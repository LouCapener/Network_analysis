# %%
import re
import pandas as pd
import os

# %%
df = pd.read_csv('Data/regex_df.csv')

# %%
df
# Out:
#         season  episode                            title  \
# 0     SEASON 1        1       Cartman Gets an Anal Probe
# 1     SEASON 1        2                 Weight Gain 4000
# 2     SEASON 1        3                          Volcano
# 3     SEASON 1        4   Big Gay Al's Big Gay Boat Ride
# 4     SEASON 1        5  An Elephant Makes Love to a Pig
# ..         ...      ...                              ...
# 316  SEASON 26        2       The Worldwide Privacy Tour
# 317  SEASON 26        3                  Japanese Toilet
# 318  SEASON 26        4                    Deep Learning
# 319  SEASON 26        5               DikinBaus Hot Dogs
# 320  SEASON 26        6                     Spring Break
#
#                                                    url  \
# 0    https://southpark.fandom.com/wiki/Cartman_Gets...
# 1    https://southpark.fandom.com/wiki/Weight_Gain_...
# 2     https://southpark.fandom.com/wiki/Volcano/Script
# 3    https://southpark.fandom.com/wiki/Big_Gay_Al%2...
# 4    https://southpark.fandom.com/wiki/An_Elephant_...
# ..                                                 ...
# 316  https://southpark.fandom.com/wiki/The_Worldwid...
# 317  https://southpark.fandom.com/wiki/Japanese_Toi...
# 318  https://southpark.fandom.com/wiki/Deep_Learnin...
# 319  https://southpark.fandom.com/wiki/DikinBaus_Ho...
# 320  https://southpark.fandom.com/wiki/Spring_Break...
#
#                                                scripts
# 0    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# 1    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# 2    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# 3    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# 4    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# ..                                                 ...
# 316  Cast\nKyle Broflovski\nStan Marsh\nEric Cartma...
# 317  Cast\nRandy Marsh\nSharon Marsh\nShelley Marsh...
# 318  Cast\nBebe Stevens\nNelly\nRed McArthur\nNicho...
# 319  Cast\nButters Stotch\nEric Cartman\nStan Marsh...
# 320  Cast\nStan Marsh\nRandy Marsh\nHerbert Garriso...
#
# [321 rows x 5 columns]

# %%
script = df.scripts[0]

# %%
script
# Out:
# 'Cast\nStan Marsh\nKyle Broflovski\nEric Cartman\nKenny McCormick\nIke Broflovski\nChef\nMs. Crabtree\nBill Denkins\nOfficer Barbrady\nMr. Garrison\nMr. Hat\nTrain conductor\nA kid\nJason White\nWendy Testaburger\nLiane Cartman\nNews reporter\nMr. Kitty\nCarl the Visitor\nBlonde woman\nVisitors\nCows\nScript\nCartman Gets an Anal Probe\nAt the bus stop.\nThe boys\nSchool days, school days, teacher\'s golden ru... [Ike runs to the team]\nKyle Broflovski\nAh, damn it! My little brother\'s trying to follow me to school again.\nIke Broflovski\nEe gko zeeponanner.\nKyle\nIke, you can\'t come to school with me. [Ike chortles.]\nEric Cartman\nYeah, go home you little dildo!\nKyle\nDude, don\'t call my brother a dildo!\nStan Marsh\nWhat\'s a dildo?\nKyle\nWell, I don\'t know...[faces Cartman and points at him.] and I\'ll bet Cartman doesn\'t know either!\nCartman\nI know what it means!\nKyle\nWell, what?\nCartman\nI\'m not telling you.\nStan\nWhat\'s a dildo, Kenny?\nKenny McCormick\n(It\'s a giant stick that goes inside the mom’s vagina.) [The others laugh.]\nCartman\nHe-yeah, that\'s what Kyle\'s little brother is all right! [Kyle swings Ike by his feet, knocking Cartman down.] Ow! [Ike laughs.]\nStan\nDude, that kicks ass!\nKyle\nYeah, check this one out. Ready Ike? Kick the baby!\nIke\nDon\'t kick the baby.\nKyle\nKick the baby.\nHe kicks Ike like a football, who lands, knocking down four mailboxes. Cartman yawns.\nStan\nWhoa, Cartman! Looks like you didn\'t get much sleep last night.\nCartman\nThat\'s \'cause I was having these bogus nightmares.\nKyle\nReally? What about?\nCartman\nWell, I dreamt that I was lying in my bed...\nThe dream sequence begins.\nCartman\n...in the dark, when all of a sudden this bright blue light filled the room.\nThrough his window, one can see a spaceship land and its light stream in.\nCartman\nThen slowly my bedroom door began to open... [A visitor peeks inside.]\nCartman\n...and then the next thing I remember, I was being drug through a hallway.\nCartman\nWeeaak!\nCartman\nThen I was lying on a table...\nCartman is laying face down, Visitors lower his pajamas.\nCartman\n...and these scary aliens wanted to operate on me. And they had big heads and big black eyes.\nThe dream sequence ends.\nStan\nDude! Visitors!\nKyle\nTotally!\nCartman\nWhat?\nStan\nThat wasn\'t a dream Cartman, those were visitors!\nCartman\nNo, it was just a dream, my mom said so.\nStan\nVisitors are real.\nKyle\nYeah, they abduct people and they mutilate cows.\nCartman\nOh, shut up, guys! You\'re just trying to make me scared. And it\'s not working.\nJerome "Chef" McElroy\n[drives up and gets out of the car.] Hello there, children.\nBoys\n[in unison] Hey, Chef.\nStan\nWhat\'s gonna be for lunch today, Chef?\nChef\nWell, today it\'s Salisbury steak with buttered noodles and a choice of green bean casserole or vegetable medley.\nCartman\nKick ass.\nChef\nSay, did any of you children see the alien space ship last night?\nCartman\n[surprised.] Huh?\nKyle\nYeah, fat boy saw it!\nCartman\nEh, no, that, that was just a dream. And I\'m not fat, I\'m big boned!\nChef\nOh, was it the ones with the big long heads and the black eyes?\nCartman\nOh!\nStan\nThey took him on their ship.\nChef\nOh! [quietly.] Did they give you an anal probe?\nCartman\nOh!\nKyle\nWhat\'s an anal probe?\nChef\nThat\'s when they put this big metal hoop-a-joop up yo\' butt.\nKyle\nWhoa! They gave you an anal probe Cartman?\nCartman\nNo! Uh-I mean, eh, why would they do that?\nStan\nDude, they did, huh? Aliens stuck stuff up your ass!\nCartman\nNo!\nIke\nEneh probe.\nCartman\nShut up, dildo!\nChef\nWell, I gotta get to the cafeteria. You children watch that fat boy now. He could be under alien control.\nChef walks back to his car, there is a picture of a Visitor on his shirt with the word "Believe" written under it. Cartman goes catatonic as Chef drives off.\nCartman\nOh!\nKyle\nWe told you they were real Cartman. Sorry to hear about your ass.\nCartman\nGod damn it, the ...

# %% [markdown]
# # Remove anything inbetween square brackets
#
# (Including the square brackets themselves).
#
# You'll notice in the script above that we have some text within brackets which describes character's behaviour.
#
# E.g.:
#
# * [Ike chortles.]
# * [They laugh.]
# * [His voice is rising to an audible level.]
#
# This is interesting info but nonetheless irrelevant for our main aims, so we're going to trawl through every script in our dataframe and remove text within the square brackets, as well as the square brackets themselves.
#
# REGEX PATTERN = \[.*?]
#
# * \[ - finds the first opening square bracket. \ is an escape sequence used to match a character which usually has a special meaning. Square brackets usually indicate a character class.
#
# * . - meta-character which matches any one character
#
# * asterix is an occurance indicator which indicates to match 0 or more times
#
# * ? - is a lazy operator which when used after * makes the occurance indicator non-greedy, meaning it'll match as few characters as possible.
#
# Removing the ? would make this regex pattern greedy, meaning it matched everything from the first open bracket to the last open bracket. E.g. it'd return this: ['[example1] some text [example2]']
#
# Whereas, keeping it means we match as few characters as possible to stop at the first closing bracket, allowing for multiple matches. E.g. we'd get separate matches: ['[example1]', '[example2]']
#
# **NOTE:** If we just wanted to capture the text within the square brackets, we'd use '()' to capture a group.

# %% [markdown]
# ## Small test

# %%
df.scripts[9] = df.scripts[9].replace("[Clouds begin to conceal the sun.", "[Clouds begin to conceal the sun.]")
# Out:
# /var/folders/dm/468m4xf52c71yhldz5ck50pw0000gn/T/ipykernel_58121/203647860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.scripts[9] = df.scripts[9].replace("[Clouds begin to conceal the sun.", "[Clouds begin to conceal the sun.]")

# %%
test = re.sub("\[.*?]", '', script, flags = re.DOTALL)

# %%
test
# Out:
# 'Cast\nStan Marsh\nKyle Broflovski\nEric Cartman\nKenny McCormick\nIke Broflovski\nChef\nMs. Crabtree\nBill Denkins\nOfficer Barbrady\nMr. Garrison\nMr. Hat\nTrain conductor\nA kid\nJason White\nWendy Testaburger\nLiane Cartman\nNews reporter\nMr. Kitty\nCarl the Visitor\nBlonde woman\nVisitors\nCows\nScript\nCartman Gets an Anal Probe\nAt the bus stop.\nThe boys\nSchool days, school days, teacher\'s golden ru... \nKyle Broflovski\nAh, damn it! My little brother\'s trying to follow me to school again.\nIke Broflovski\nEe gko zeeponanner.\nKyle\nIke, you can\'t come to school with me. \nEric Cartman\nYeah, go home you little dildo!\nKyle\nDude, don\'t call my brother a dildo!\nStan Marsh\nWhat\'s a dildo?\nKyle\nWell, I don\'t know... and I\'ll bet Cartman doesn\'t know either!\nCartman\nI know what it means!\nKyle\nWell, what?\nCartman\nI\'m not telling you.\nStan\nWhat\'s a dildo, Kenny?\nKenny McCormick\n(It\'s a giant stick that goes inside the mom’s vagina.) \nCartman\nHe-yeah, that\'s what Kyle\'s little brother is all right!  Ow! \nStan\nDude, that kicks ass!\nKyle\nYeah, check this one out. Ready Ike? Kick the baby!\nIke\nDon\'t kick the baby.\nKyle\nKick the baby.\nHe kicks Ike like a football, who lands, knocking down four mailboxes. Cartman yawns.\nStan\nWhoa, Cartman! Looks like you didn\'t get much sleep last night.\nCartman\nThat\'s \'cause I was having these bogus nightmares.\nKyle\nReally? What about?\nCartman\nWell, I dreamt that I was lying in my bed...\nThe dream sequence begins.\nCartman\n...in the dark, when all of a sudden this bright blue light filled the room.\nThrough his window, one can see a spaceship land and its light stream in.\nCartman\nThen slowly my bedroom door began to open... \nCartman\n...and then the next thing I remember, I was being drug through a hallway.\nCartman\nWeeaak!\nCartman\nThen I was lying on a table...\nCartman is laying face down, Visitors lower his pajamas.\nCartman\n...and these scary aliens wanted to operate on me. And they had big heads and big black eyes.\nThe dream sequence ends.\nStan\nDude! Visitors!\nKyle\nTotally!\nCartman\nWhat?\nStan\nThat wasn\'t a dream Cartman, those were visitors!\nCartman\nNo, it was just a dream, my mom said so.\nStan\nVisitors are real.\nKyle\nYeah, they abduct people and they mutilate cows.\nCartman\nOh, shut up, guys! You\'re just trying to make me scared. And it\'s not working.\nJerome "Chef" McElroy\n Hello there, children.\nBoys\n Hey, Chef.\nStan\nWhat\'s gonna be for lunch today, Chef?\nChef\nWell, today it\'s Salisbury steak with buttered noodles and a choice of green bean casserole or vegetable medley.\nCartman\nKick ass.\nChef\nSay, did any of you children see the alien space ship last night?\nCartman\n Huh?\nKyle\nYeah, fat boy saw it!\nCartman\nEh, no, that, that was just a dream. And I\'m not fat, I\'m big boned!\nChef\nOh, was it the ones with the big long heads and the black eyes?\nCartman\nOh!\nStan\nThey took him on their ship.\nChef\nOh!  Did they give you an anal probe?\nCartman\nOh!\nKyle\nWhat\'s an anal probe?\nChef\nThat\'s when they put this big metal hoop-a-joop up yo\' butt.\nKyle\nWhoa! They gave you an anal probe Cartman?\nCartman\nNo! Uh-I mean, eh, why would they do that?\nStan\nDude, they did, huh? Aliens stuck stuff up your ass!\nCartman\nNo!\nIke\nEneh probe.\nCartman\nShut up, dildo!\nChef\nWell, I gotta get to the cafeteria. You children watch that fat boy now. He could be under alien control.\nChef walks back to his car, there is a picture of a Visitor on his shirt with the word "Believe" written under it. Cartman goes catatonic as Chef drives off.\nCartman\nOh!\nKyle\nWe told you they were real Cartman. Sorry to hear about your ass.\nCartman\nGod damn it, they didn\'t do anything to my ass! It was just a dream!\nThey start to file onto the bus.\nKyle\nWhy you walkin\' so funny Cartman?\nCartman\nShut up!\nIke\n Oh foonuh bebe.\nKyle\nNo, Ike, go home.\nIke\nEeeeee!\nKyle\nThis is it. This one\'s for the  ...

# %%
matches = re.findall("\[.*?]", script, flags=re.DOTALL)

# %%
s = df.scripts

# %%
brackets = s.str.findall("\[.*?]", flags = re.DOTALL)

# %%
from __future__ import unicode_literals
import spacy,en_core_web_sm
import textacy
nlp = en_core_web_sm.load()

# %%
import spacy   
from spacy.matcher import Matcher
from spacy.util import filter_spans
# instantiate a Matcher instance
matcher = Matcher(nlp.vocab)
pattern = [{'POS':'VERB'}]
matcher.add("Verb", [pattern])
nlp = spacy.load('en_core_web_sm') 
verbs = []

for i in brackets:
    for x in i:
        doc = nlp(x)
        matches = matcher(doc)
        spans = [doc[start:end] for _, start, end in matches]
        for verb in spans:
            if verb != None:
                verbs.append(spans)

# %%
brackets[69]
# Out:
# ['[voice only]',
#  "[shot of the TV, with the camera panning up to reveal Punky Brewster sitting in a director's chair]",
#  "[image of Punky makes room for the show's logo on the right side]",
#  '[Cartman changes the channel]',
#  '[Shot of TV as "The Terrance & Phillip Show" begins]',
#  '[farts]',
#  '[both laugh]',
#  '[faaaaaaaaaaaaaaaart. Whatever Terrance is saying is drowned out by the fart]',
#  '[boys join in]',
#  '[Kyle chimes in]',
#  '[Terrance lowers his pants enough to show his ass; Phillip sticks his finger in there]',
#  "[now wearing a mechanic's hat]",
#  "[the two laugh, then the boys laugh, then the laughter dies down. Terrance farts again, and they both laugh as the camera's iris shuts slowly.]",
#  '[toilet water erupts from the toilet and blows them off camera]',
#  '[On TV, "HEY KIDS!!," white on green, appears and gets bigger, then dances on a blinking background]',
#  '["Terrance and Phillip LIVE! And in person" appears, then Terrance and Phillip flank the text on either side]',
#  '[scenes from various episodes appear]',
#  '[Kenny starts babbling incoherently]',
#  '[running in circles]',
#  '[a crawl at the bottom of the screen, black on red, reads "CALL NOW! 555-TIXS"]',
#  '[Kyle gives them out]',
#  '[enters and goes before the chalkboard]',
#  '[writes it on the board]',
#  '[moves aside for the heads. Two men and a woman come in, each of them sporting a bow on the left lapel.]',
#  '[slowly waves his left forearm in a broad arc, to the left, palm out]',
#  '[the boys stir and the camera closes in]',
#  '[slowly waves his left forearm in a broad arc, to the left, palm out]',
#  '[the boys stare back]',
#  '[draws close and repeats the arm movement]',
#  '[to the woman at his left, whispers]',
#  '[fielding]',
#  '[to the older man]',
#  '[ominously]',
#  '[the boys look sufficiently scared]',
#  '[the kids cheer and hoot. Spotlights wash over the audience, their beams moving around aimlessly]',
#  '[only one spotlight remains on, illuminating the mic, and the music cuts off]',
#  '[approaches the mic from behind the curtains]',
#  "[the roar of the audience fades quickly as they see only Terrance there, and he's not quite himself. A smattering of applause follows]",
#  '[Terrance farts and the audience claps awkwardly]',
#  '[farts, and laughs]',
#  '["Phil-lip! Phil-lip!"]',
#  '[the crowd cheers and music plays a bit]',
#  '[bends down to receive the fart. Terrance bends over and farts on "Phillip\'s" face. They both laugh]',
#  '[he and his partner pull out top hats]',
#  '[they reach the dressing room, but a bouncer stands in the way]',
#  '[points to the line, which has a lot more kids waiting to see Terrance. The boys turn to see...]',
#  '[the boys head for the end of the line]',
#  '[a boy wearing glasses watches the foursome approach. The boys fall in]',
#  '[quite timidly]',
#  '[a post next to it reads "FEMALE GROUPIES AND OTHER RANDOM SLUTS" An obese woman stands last in line]',
#  "[a look of anger flashes across Kenny's face]",
#  '[moves to the other line. His friends follow.]',
#  "[stretches the fat woman's pants enough so that all four of them climb in and disappear under her fat]",
#  '[spanks her twice]',
#  '[they separate a bit]',
#  '[stands her up quickly and she looks back, disappointed in his reaction]',
#  '[the obese woman comes in happily]',
#  '[voice trembling]',
#  '[starts making out with him]',
#  '[lays down on the sofa, under her]',
#  '[the woman unzips his pants, then her own]',
#  '[coitus ensues]',
#  '[reaching climax]',
#  "[Cartman leaps out the back of the woman's pants]",
#  '[Terrance and the woman stand up]',
#  '[the other three boys climb out]',
#  '[the woman throws up her arms and runs out screaming]',
#  '[gets a pen and paper]',
#  '[crosses his arms and looks mad]',
#  '[shot of the boys listening]',
#  '[sulks away from the sofa]',
#  '[walks to his dresser and mirror. The boys are seen in the reflection]',
#  '[turns around to face the boys]',
#  '[wistfully]',
#  '[does a quote with his index and middle fingers from both hands]',
#  '[pleading]',
#  '[the boys look at each other in dismay]',
#  '[through a bullhorn]',
#  '[waves his right forearm slowly to the right, palm out]',
#  '[repeats the arm movement]',
#  '[turns and returns to work. Stan and friends come in from the other direction and stop at a sign announcing Terrance and Phillip: "TERRANCE & PHILLIP As Promised By KYLE AND HIS FRIENDS"]',
#  '[arriving with his assistants]',
#  '[gravely]',
#  '[the three of them start to move away]',
#  '[leaves]',
#  "[leaps on his rival, and both lose their swords. The two scuffle on the floor for a few seconds. Phillip's rival fends him off, but Phillip picks up the rival's sword and wounds him with it. We soon learn this is Act 5, Scene 2 of the play, the finale. And so...]",
#  '[Phillip]',
#  '[falls]',
#  '[steps forth.]',
#  '[Hamlet looks over his left shoulder]',
#  '[Hamlet goes to check on the Queen]',
#  '[in the audience Stan and Kyle sigh deeply and Kenny plays with a toy plane, Cartman is asleep]',
#  '[dies]',
#  '[genuflects next to the poisoned sword]',
#  '[picks up the poisoned sword]',
#  '[Stabs King Claudius]',
#  '[dies]',
#  '[dies]',
#  '[chuckles]',
#  '[chuckles]',
#  '[Kenny continues playing with his plane]',
#  '[dies]',
#  '[reaching Phillip]',
#  '[stammering]',
#  '[farts and laughs despite himself]',
#  '[opens the driver-side door]',
#  '[hands Stan a business card]',
#  '[peels away]',
#  '[silent for a bit, then]',
#  '[through a bullhorn]',
#  '[they approach and ascend a stage set up for Terrance and Phillip. Stan and friends are already there, waiting]',
#  '[moves to stand behind the boys with his assistants flanking him]',
#  "[the younger man, now known as Carl, takes an Earth Day meat cleaver and chops off Kenny's left hand]",
#  '[arriving]',
#  '[Stan and Cartman smile]',
#  '[Terrance enters from the other side of the stage.]',
#  '[angrily]',
#  '[a zoom-out shows Terrance and Phillip facing away from each other]',
#  '[moves his left forearm, palm out, from right to left]',
#  '[the boys leave the stage]',
#  '[the boys take their places before the committee]',
#  '[poots]',
#  '[encouraging, claps]',
#  '[interrupts]',
#  '[moves off the stage, left]',
#  "[Carl pulls out the cleaver again and chops off Kenny's right hand.]",
#  '[He, Carl, and the woman walk away. The boys move towards Kenny]',
#  '[a woman on stage sings and plays a guitar]',
#  '[one shot of the booths]',
#  '[a shot of more booths]',
#  "[an inset of the boys appears over the reporter's left shoulder]",
#  '[takes the mic as the singer leaves]',
#  '[sweeps his left forearm, palmout, from right to left]',
#  '[repeating]',
#  '[the crowd cheers and claps. Jack gives the mic to Kyle and walks off. Stan has left the stage]',
#  '[the crowd nose dies down]',
#  '[Stan hands a tape to a camera man, who puts it into a VCR and starts it.]',
#  '[the curtains part on stage, revealing "EARTH DAY 2001"]',
#  '[a shot of the duo, then another of them with Tony Orlando and Dawn]',
#  "[a shot of Terrance, slumped over his couch, then of the show's logo, with vigorous music]",
#  '[approaching the boys]',
#  '[Jack and the woman show up]',
#  '[Carl wields the cleaver one more time, and it reads "Earth Day Cleaver 2001." The boys make a run for it]',
#  '[they run behind the crowd as the committee pursues them]',
#  '[the show resumes]',
#  '[shown with his parents. Mom is a Mountie, Dad seems to be a lumberjack]',
#  '[a shot of Terrance playing a xylophone, then of the school building, then of Terrance in a class picture with other toddlers]',
#  '[soon highlighted]',
#  '[a shot of a poster announcing their next performance]',
#  '[stock footage of Las Vegas in the 1960s]',
#  '[stock footage of the building the show was filmed at]',
#  '[arms folded over his chest]',
#  '[fanfare, audience claps as the two boys are shown in Canadian Mountie dress. They begin their song and dance]',
#  '[one person claps. Ed looks disappointed]',
#  '[Phillip farts. A man and woman laugh, and soon the audience joins in. Ed claps joyfully as well. The crowd is soon roaring with cheers and then Terrance farts in return. More laughter and cheers]',
#  '[a shot of Terrance and Phillip using their fart routine in their music act, a shot of them with President Gerald Ford]',
#  '[a shot of the audience looking at the video, from the back of the audience]',
#  '[approaches Mr. Garrison]',
#  '[still mad, carries a suitcase]',
#  '[points to the stage]',
#  '[looks at the screen]',
#  '[splashy shots of the Sonny & Cher Show]',
#  '[garbled somewhat]',
#  '[the audience laughs]',
#  '[applause and music as the duo come on]',
#  '[farts in his direction, and they both laugh. The audience laughs along]',
#  "[farts on Terrance's face, and they both laugh, and the audience joins in. Terrance farts on Phillip's face and they both laugh. The audience laughs some more. Terrance farts on Cher and Phillip farts on Sonny]",
#  '[the shot of Terrance and Phillip with Tony Orlando and Dawn]',
#  '[panting]',
#  '[off-screen]',
#  '[the boys react and are off running]',
#  "[Carl chops off Kenny's left leg to the knee]",
#  '[Kyle wails, Kenny keeps up somehow]',
#  '[a shot of Terrance and Phillip with three Playboy Bunnies]',
#  '[a shot of Terrance and Phillip propped up as scarecrows out on a field]',
#  '[a shot of Johnny Carson laughing it up with Terrance and Phillip]',
#  '[a shot of the Donny and Marie Show with Terrance and Phillip cavorting in the background]',
#  '[The Times, Teen Heat]',
#  '[From episode #102, "Terrance and Phillip and the Land of the Goat People." The camera pans an alien landscape, from a star in the sky to a pair of muscular men in spandex space suits]',
#  '[farts, and they both laugh]',
#  '[approaches with his tribe]',
#  '[he and Terrance laugh. The dialog continues as the narrator speaks]',
#  '[a shot of them working on a script]',
#  '[a shot of the duo on the Metro, then the opening logo is shown, then shots of the episode itself]',
#  '[a shot of John singing]',
#  '[a clip of Terrance and Phillip on the Metro]',
#  '[a shot of the HBC building in flames]',
#  '[a shot of the dead and wounded, another of rioting]',
#  '[Terrance sits slumped over his sofa with a small can of polish at his feet]',
#  '[a shot of teen Terrance and Phillip superimposed on a burning HBC building]',
#  '[moves into view, looking at the video]',
#  "[he's behind and next to Mr. Mackey]",
#  '[a shot of Terrance on a yellow sofa, drunk and unkempt, attempting to hammer himself to death]',
#  '[another shot of them working on a script]',
#  '[a poster for Asses of Fire is shown, then the camera zooms on on the duo in the car]',
#  '[shots of the duo singing and dancing in the street, during "Uncle Fucka"]',
#  '[shots of the war]',
#  '[a shot of Terrance and Phillip holding an Oscar]',
#  '[a shot of the attempted execution]',
#  '[they are shown getting off the plane, with the captain waving at them from behind]',
#  '[a shot of Phillip looking at the video]',
#  '[a shot of the duo being hoisted above the crowd, Terrance holding a golden cup.]',
#  '[the audience cheers and claps. Terrance walks up to Phillip, still with suitcase]',
#  '[pause]',
#  '[pause]',
#  '[drops the suitcase and makes a move]',
#  '[awkward pause]',
#  '[now dejected]',
#  "[now dejected. Phillip farts long and soft. A few laughs roll out of Phillip, then out of Terrance, and pretty soon they're laughing it up as they always do. The Earth Day committee approaches the boys, who have made it back to the festival]",
#  "[Carl chops off Kenny's right leg with the cleaver]",
#  '[topples over and away from the committee. Large amounts of blood quickly pour out]',
#  '[he and the other two start to move off]',
#  '[the audience cheers as Terrance and Phillip take the stage]',
#  '[both fart]',
#  '[both of them laugh]',
#  '[rolling Kenny over so he can see]',
#  '[the camera pulls out as the skit continues]']

# %%
fin_verbs = []

for i in verbs:
    for words in i:
        print(words)
        fin_verbs.append(words)
# Out:
# runs
# chortles
# faces
# laugh
# knocking
# laughs
# drives
# gets
# drives
# gets
# Waddles
# Turning
# see
# Turning
# see
# runs
# laugh
# drowned
# rising
# walks
# shouts
# fire
# Drives
# flashing
# Drives
# flashing
# pursues
# fire
# hands
# leaves
# follow
# glances
# gets
# shouts
# hear
# shouts
# hear
# Turning
# face
# Turning
# face
# Pulling
# gets
# gets
# walks
# hurries
# walks
# stops
# Turns
# moves
# walks
# following
# walks
# following
# walks
# fire
# looks
# Driving
# stops
# Driving
# stops
# appear
# shrugs
# leave
# Thinking
# Passing
# Stopping
# singing
# Turning
# face
# Turning
# face
# Shrieking
# Hushed
# Rushing
# Takes
# run
# Flashes
# Crowd
# Snapping
# Muffled
# Whining
# Arresting
# Drops
# Beeps
# Thump
# turns
# Rowing
# Shoots
# Sees
# dressed
# Sees
# dressed
# Hushed
# drops
# leave
# Looking
# distracted
# sees
# laugh
# starts
# punches
# punches
# leaves
# enter
# heckling
# rushes
# shaking
# mocking
# Whining
# laughs
# Wagging
# Pissed
# Swooning
# Heading
# labored
# stopping
# hushed
# pointing
# concerned
# darting
# leans
# Getting
# Taunting
# torches
# begin
# conceal
# begin
# conceal
# Holding
# Sees
# coming
# Sees
# coming
# moves
# Falls
# Drops
# leaves
# leaves
# Thumps
# Tosses
# pinned
# Slapping
# Gets
# moves
# Gets
# moves
# Swings
# pick
# ends
# looks
# Turning
# Thinks
# Puts
# laughing
# Rushing
# Panicking
# throws
# sobbing
# throws
# sheds
# turns
# walks
# sheds
# turns
# walks
# sheds
# turns
# walks
# starts
# starts
# sway
# starts
# starts
# sway
# starts
# starts
# sway
# grins
# Enunciating
# Looks
# Feigning
# clearing
# Feigning
# clearing
# opens
# opens
# Waving
# screaming
# continues
# Shows
# gains
# Strolling
# Examines
# Revealing
# Braking
# starts
# convulsing
# starts
# convulsing
# crushes
# steps
# watching
# steps
# watching
# throws
# rips
# grabs
# drops
# throws
# rips
# grabs
# drops
# throws
# rips
# grabs
# drops
# throws
# rips
# grabs
# drops
# looks
# mortified
# opens
# looks
# mortified
# opens
# looks
# mortified
# opens
# takes
# Looks
# looks
# ends
# stands
# Takes
# resumes
# playing
# resumes
# playing
# Weighs
# begins
# play
# begins
# play
# plays
# Interrupting
# looks
# follows
# looks
# follows
# come
# start
# kissing
# come
# start
# kissing
# come
# start
# kissing
# cupped
# playing
# Studying
# Drags
# Does
# Dejected
# pulls
# throws
# Moves
# Grabs
# Looks
# look
# dances
# Approaching
# stops
# Turns
# turns
# picks
# walks
# picks
# walks
# drops
# Jumps
# turns
# see
# Jumps
# turns
# see
# Jumps
# turns
# see
# Trying
# Blinks
# Eyebrows
# Looks
# Looks
# Looks
# Pissed
# scratches
# Enunciating
# heard
# plays
# laugh
# Approaching
# Bangs
# Thumps
# Coming
# Wondering
# leave
# laugh
# leaves
# dressed
# Reads
# Takes
# Takes
# turns
# leave
# turns
# leave
# join
# looks
# Returning
# Thumps
# Thumps
# Hangs
# gasp
# go
# runs
# blows
# blows
# go
# runs
# blows
# blows
# go
# runs
# blows
# blows
# go
# runs
# blows
# blows
# Embraces
# Pulls
# Walking
# Goes
# Listening
# Getting
# Grabbing
# lift
# Aroused
# Close
# Rises
# follows
# pass
# Pained
# Grabs
# Drops
# departs
# drawn
# Looking
# Falls
# speaks
# appears
# seen
# flinch
# throws
# flinch
# throws
# Catches
# Opening
# Opens
# Snuggling
# Rubs
# raises
# withdraws
# covers
# shown
# squatting
# shown
# squatting
# keep
# eating
# keep
# eating
# Drops
# widen
# Pulls
# Coming
# pulls
# Boiling
# looks
# looks
# come
# floats
# Takes
# Coming
# Pulls
# Puts
# Drives
# Slaps
# Wipes
# Turns
# Wringing
# Throttling
# leave
# Walks
# Points
# Takes
# Steps
# carried
# looks
# moves
# Taking
# Doing
# checks
# Winking
# Displays
# Stepping
# Pulls
# Reading
# Recalls
# Sips
# Takes
# Gets
# Rushing
# puts
# Going
# Turns
# Lowers
# Enunciating
# Leaning
# Imitating
# Following
# Thumps
# Sobbing
# Starts
# move
# Starts
# move
# Peels
# Rushing
# Smoking
# get
# gasps
# Holds
# drops
# leaves
# Doing
# starts
# sob
# starts
# sob
# leave
# Getting
# Grousing
# Gives
# Pointing
# reach
# Subdued
# tosses
# Gives
# flips
# sporting
# looks
# draws
# looks
# embrace
# Gets
# get
# moves
# Follows
# looking
# Blows
# Giggling
# falls
# Arriving
# Rising
# Sits
# Grumbling
# begins
# Reaches
# Interrupting
# Vindicated
# Laying
# Walking
# Reads
# Wiping
# flies
# Firing
# Reading
# talk
# Pounds
# whispers
# bandaged
# Popping
# Thinks
# Holding
# Resumes
# filming
# Resumes
# filming
# Pops
# Moves
# Looks
# Relishing
# Sobbing
# Pinned
# Retreating
# Comes
# stands
# Comes
# stands
# Finishes
# Turns
# baiting
# Resumes
# eating
# Resumes
# eating
# Turns
# starts
# Shouting
# begins
# hyperventilate
# begins
# hyperventilate
# sits
# turns
# face
# turns
# face
# Faces
# Facing
# Holds
# Rushing
# Sees
# Thinks
# Running
# Drops
# Pointing
# hurrying
# get
# look
# get
# look
# reaches
# Switch
# Switch
# Hangs
# Emerging
# Pushes
# Drives
# Writes
# Grins
# Looking
# answers
# hangs
# resumes
# hangs
# resumes
# notice
# Walking
# Rushing
# Passing
# Taunting
# walk
# Moaning
# Rushing
# Rising
# Gasping
# Turns
# Determined
# talking
# hanging
# talking
# hanging
# Sitting
# Mocking
# Picks
# Looking
# crossed
# pulls
# Happening
# Stopping
# Singing
# Weeping
# Concerned
# Arriving
# Facing
# Turns
# face
# Turns
# face
# Rushes
# returns
# Put
# pulls
# tosses
# Flying
# Crying
# Recovering
# Fleeing
# Gazing
# Stopping
# scratches
# Intruding
# Setting
# Walks
# Scanning
# finished
# setting
# finished
# setting
# creeps
# Hushed
# Turning
# Recoiling
# Whining
# Whining
# Threatening
# spits
# Turns
# Closing
# Releases
# trails
# leave
# Turns
# Subdued
# Walks
# Rushing
# Pointing
# Rising
# Rising
# Gets
# leaves
# throws
# Puffs
# Hiding
# Coming
# shut
# stare
# Rubbing
# Whining
# amused
# appears
# connecting
# appears
# connecting
# Clears
# affects
# Clears
# affects
# Slapping
# Tallying
# popping
# counting
# taunting
# Noticing
# Responding
# Turning
# appears
# opens
# pour
# opens
# pour
# rain
# swim
# rain
# swim
# Doing
# Snapping
# skipping
# Coming
# Rushing
# Snapping
# Looking
# Intrigued
# Walks
# Thinks
# trying
# Stopping
# Sliding
# Enunciating
# Rubs
# walks
# Wiggling
# Entering
# Staring
# leaves
# Staring
# leaves
# Seated
# Pulls
# shaking
# Muffled
# Running
# step
# Thinks
# Pulls
# Ignoring
# speaking
# Ignoring
# speaking
# stops
# Grabbing
# Whispers
# wavering
# Passes
# Putting
# Senses
# Hangs
# Rushing
# walk
# Pulls
# Examining
# Dejected
# starts
# sobbing
# starts
# sobbing
# Vocalizing
# Walks
# Dropping
# turns
# closes
# turns
# closes
# lifts
# looks
# sits
# swims
# lifts
# looks
# sits
# swims
# lifts
# looks
# sits
# swims
# lifts
# looks
# sits
# swims
# gets
# picks
# throws
# goes
# looks
# gets
# picks
# throws
# goes
# looks
# gets
# picks
# throws
# goes
# looks
# gets
# picks
# throws
# goes
# looks
# gets
# picks
# throws
# goes
# looks
# pulls
# knock
# opens
# looks
# see
# opens
# looks
# see
# opens
# looks
# see
# dressed
# look
# walks
# hops
# approaches
# hops
# approaches
# blinks
# looks
# follow
# sees
# blinks
# looks
# follow
# sees
# blinks
# looks
# follow
# sees
# blinks
# looks
# follow
# sees
# runs
# pulls
# drops
# looks
# runs
# pulls
# drops
# looks
# runs
# pulls
# drops
# looks
# runs
# pulls
# drops
# looks
# shuts
# opens
# shuts
# opens
# shuts
# opens
# shuts
# opens
# shuts
# opens
# shuts
# opens
# jumps
# runs
# rushes
# jumps
# runs
# rushes
# jumps
# runs
# rushes
# comes
# walks
# buries
# begins
# sob
# buries
# begins
# sob
# buries
# begins
# sob
# looks
# runs
# enters
# turns
# enters
# turns
# pointing
# left
# stands
# approaches
# slaps
# leaves
# stands
# approaches
# slaps
# leaves
# stands
# approaches
# slaps
# leaves
# stands
# approaches
# slaps
# leaves
# turns
# closes
# turns
# closes
# gasps
# lies
# gasps
# lies
# freezes
# sees
# quivering
# freezes
# sees
# quivering
# freezes
# sees
# quivering
# rushes
# comfort
# rushes
# comfort
# covers
# kisses
# gets
# kisses
# gets
# starts
# drag
# starts
# drag
# drags
# looks
# drags
# looks
# turns
# writes
# blows
# writes
# blows
# appears
# sees
# pass
# sees
# pass
# enters
# holds
# holds
# looks
# drags
# looks
# drags
# brings
# sets
# brings
# sets
# says
# enters
# says
# enters
# squeezes
# walks
# squeezes
# walks
# cuts
# clear
# cuts
# clear
# works
# goes
# comes
# gives
# look
# seeing
# walks
# rings
# answering
# show
# missing
# show
# missing
# moves
# head
# await
# pulling
# pulls
# walks
# moves
# head
# await
# pulling
# pulls
# walks
# moves
# head
# await
# pulling
# pulls
# walks
# moves
# head
# await
# pulling
# pulls
# walks
# moves
# head
# await
# pulling
# pulls
# walks
# moves
# head
# await
# pulling
# pulls
# walks
# falls
# hit
# falls
# hit
# missing
# tied
# missing
# tied
# dressed
# points
# are
# blink
# points
# are
# blink
# points
# are
# blink
# rubs
# shaking
# hops
# hops
# rejoins
# hops
# rejoins
# turns
# takes
# turns
# takes
# walks
# rushing
# holds
# points
# dragging
# swims
# jumps
# pulls
# jumps
# pulls
# starts
# gargle
# gives
# turns
# spins
# starts
# gargle
# gives
# turns
# spins
# starts
# gargle
# gives
# turns
# spins
# starts
# gargle
# gives
# turns
# spins
# starts
# gargle
# gives
# turns
# spins
# spits
# jumps
# gone
# spits
# jumps
# gone
# spits
# jumps
# gone
# returning
# sees
# rush
# munch
# sees
# rush
# munch
# sees
# rush
# munch
# drags
# looks
# drags
# looks
# walk
# trying
# open
# walk
# trying
# open
# walk
# trying
# open
# turns
# turns
# keeps
# trying
# turns
# keeps
# trying
# turns
# keeps
# trying
# dressed
# pull
# stab
# laugh
# pull
# stab
# laugh
# pull
# stab
# laugh
# slaps
# looks
# picks
# purring
# amused
# purring
# amused
# jumps
# approaches
# sits
# cradling
# holds
# throttles
# holds
# throttles
# intervening
# escorts
# enters
# reach
# enters
# reach
# takes
# goes
# addresses
# goes
# addresses
# pounds
# holds
# pulls
# show
# groan
# have
# blinks
# glow
# pulls
# show
# groan
# have
# blinks
# glow
# pulls
# show
# groan
# have
# blinks
# glow
# pulls
# show
# groan
# have
# blinks
# glow
# pulls
# show
# groan
# have
# blinks
# glow
# pulls
# show
# groan
# have
# blinks
# glow
# opens
# marked
# flashing
# opens
# marked
# flashing
# opens
# marked
# flashing
# turns
# see
# rushes
# turns
# see
# rushes
# turns
# see
# rushes
# rolling
# begins
# cutting
# begins
# cutting
# makes
# comes
# pounds
# takes
# turns
# face
# turns
# face
# looks
# exit
# puts
# opens
# glowing
# puts
# opens
# glowing
# puts
# opens
# glowing
# appear
# pulls
# starts
# releasing
# bashing
# starts
# releasing
# bashing
# starts
# releasing
# bashing
# turn
# see
# attacked
# turn
# see
# attacked
# turn
# see
# attacked
# walks
# jumps
# click
# flies
# burst
# click
# flies
# burst
# click
# flies
# burst
# checks
# go
# grab
# go
# grab
# punches
# releases
# punches
# releases
# leads
# spots
# face
# pleading
# sets
# look
# return
# start
# attacking
# scream
# attacked
# look
# return
# start
# attacking
# scream
# attacked
# look
# return
# start
# attacking
# scream
# attacked
# look
# return
# start
# attacking
# scream
# attacked
# look
# return
# start
# attacking
# scream
# attacked
# look
# return
# start
# attacking
# scream
# attacked
# continues
# knocks
# continues
# knocks
# picks
# attacks
# kills
# attacks
# kills
# seeing
# happened
# seeing
# happened
# zaps
# watches
# zapped
# shrinks
# zapped
# shrinks
# takes
# takes
# wrestle
# kicks
# stand
# pulls
# takes
# wrestle
# kicks
# stand
# pulls
# takes
# wrestle
# kicks
# stand
# pulls
# takes
# wrestle
# kicks
# stand
# pulls
# takes
# wrestle
# kicks
# stand
# pulls
# pointing
# zaps
# disappears
# turns
# walks
# turns
# walks
# ignoring
# pointing
# walks
# shuts
# walks
# shuts
# retrieving
# goes
# opens
# stands
# goes
# opens
# stands
# goes
# opens
# stands
# drops
# walking
# walks
# waving
# rushing
# joins
# rushing
# joins
# opens
# find
# look
# opens
# find
# look
# opens
# find
# look
# stares
# moves
# points
# moves
# points
# points
# moved
# reaches
# pulls
# moved
# reaches
# pulls
# moved
# reaches
# pulls
# throws
# hops
# jumps
# hops
# jumps
# gets
# hops
# is
# drives
# gets
# hops
# is
# drives
# gets
# hops
# is
# drives
# gets
# hops
# is
# drives
# kicks
# rubbing
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# go
# check
# see
# says
# leaving
# changes
# covered
# pass
# see
# seen
# enunciating
# seated
# seated
# dejected
# stops
# pour
# runs
# rubs
# opens
# come
# rubs
# opens
# come
# rubs
# opens
# come
# shoves
# screams
# shoves
# screams
# shown
# approaches
# lifts
# releases
# pointing
# rips
# open
# rips
# open
# lifts
# dissenting
# turns
# have
# wear
# have
# wear
# places
# shut
# seated
# sucking
# tapping
# shows
# tosses
# slides
# tosses
# slides
# urinates
# grimaces
# urinates
# grimaces
# jabs
# dig
# fly
# dig
# fly
# watching
# stuffs
# descends
# packs
# jumps
# wakes
# breaking
# pinches
# walks
# punches
# walks
# punches
# moving
# sleeping
# moving
# sleeping
# flies
# flies
# jumps
# scream
# goes
# goes
# sees
# flies
# jumps
# scream
# goes
# goes
# sees
# flies
# jumps
# scream
# goes
# goes
# sees
# flies
# jumps
# scream
# goes
# goes
# sees
# flies
# jumps
# scream
# goes
# goes
# sees
# flies
# jumps
# scream
# goes
# goes
# sees
# shows
# broken
# shows
# broken
# turning
# pops
# makes
# pops
# makes
# turns
# express
# fall
# express
# fall
# turns
# sits
# turns
# sits
# turns
# looks
# snaps
# waking
# putting
# follows
# puts
# eating
# pops
# notices
# leaves
# walk
# reaches
# gives
# reaches
# gives
# licking
# Gone
# playing
# Gone
# playing
# coming
# hands
# digging
# sounds
# walks
# get
# calls
# irate
# jumping
# get
# jumping
# get
# looks
# seen
# stare
# moves
# stare
# moves
# walk
# looks
# sees
# lick
# begins
# cry
# looks
# sees
# lick
# begins
# cry
# looks
# sees
# lick
# begins
# cry
# looks
# sees
# lick
# begins
# cry
# looks
# sees
# lick
# begins
# cry
# grabs
# whacks
# manages
# grabs
# whacks
# manages
# grabs
# whacks
# manages
# seeing
# responding
# looks
# seeing
# responding
# looks
# seeing
# responding
# looks
# explaining
# stealing
# decorated
# stealing
# decorated
# dripping
# lift
# taken
# gasps
# cries
# gasps
# cries
# wave
# insulted
# stands
# throw
# rush
# turns
# walks
# turns
# walks
# prepare
# lights
# trimmed
# chucks
# goes
# prepare
# lights
# trimmed
# chucks
# goes
# prepare
# lights
# trimmed
# chucks
# goes
# prepare
# lights
# trimmed
# chucks
# goes
# prepare
# lights
# trimmed
# chucks
# goes
# getting
# raises
# smash
# take
# goes
# raises
# smash
# take
# goes
# raises
# smash
# take
# goes
# raises
# smash
# take
# goes
# pleased
# looks
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# race
# do
# leaves
# lies
# runs
# gives
# pumps
# fall
# resulting
# regroup
# arriving
# replaced
# arriving
# rush
# falling
# follow
# get
# backs
# jumping
# get
# backs
# jumping
# get
# backs
# jumping
# get
# pursue
# get
# pursue
# fires
# sideswipes
# loses
# drive
# sideswipes
# loses
# drive
# sideswipes
# loses
# drive
# roasting
# appears
# roasting
# appears
# tosses
# swerves
# avoid
# jump
# burst
# swerves
# avoid
# jump
# burst
# swerves
# avoid
# jump
# burst
# swerves
# avoid
# jump
# burst
# take
# rush
# walks
# pull
# walks
# pull
# opens
# laugh
# appears
# whispers
# whispers
# peek
# points
# grabs
# look
# turn
# face
# look
# turn
# face
# look
# turn
# face
# pointing
# shown
# running
# runs
# laughing
# runs
# laughing
# running
# runs
# laughing
# runs
# laughing
# running
# runs
# laughing
# runs
# laughing
# running
# runs
# laughing
# runs
# laughing
# running
# runs
# laughing
# runs
# laughing
# panting
# leave
# walks
# looks
# sees
# turns
# walks
# looks
# sees
# turns
# walks
# looks
# sees
# turns
# walks
# looks
# sees
# turns
# opens
# walking
# starts
# going
# steps
# stops
# starts
# going
# steps
# stops
# starts
# going
# steps
# stops
# starts
# going
# steps
# stops
# popping
# pondering
# hug
# walks
# opens
# get
# appears
# followed
# carrying
# opens
# get
# appears
# followed
# carrying
# opens
# get
# appears
# followed
# carrying
# opens
# get
# appears
# followed
# carrying
# opens
# get
# appears
# followed
# carrying
# fire
# killing
# breaking
# fire
# killing
# breaking
# fire
# killing
# breaking
# peering
# peering
# react
# pours
# react
# pours
# run
# handcuff
# run
# handcuff
# beat
# puts
# helping
# releases
# picks
# cuffs
# cuffed
# wrap
# reading
# puts
# walks
# puts
# walks
# turns
# heard
# turns
# heard
# turns
# see
# bears
# smiling
# roll
# bears
# smiling
# roll
# bears
# smiling
# roll
# joins
# entering
# seated
# raises
# drop
# writes
# tweaked
# lifts
# opens
# elaborates
# lifts
# opens
# elaborates
# lifts
# opens
# elaborates
# closes
# lifts
# closes
# lifts
# moves
# containing
# soothing
# comes
# moves
# containing
# soothing
# comes
# moves
# containing
# soothing
# comes
# moves
# containing
# soothing
# comes
# rolls
# protesting
# sees
# leaving
# sees
# leaving
# twitching
# closing
# twitching
# closing
# gritting
# turns
# waxing
# going
# running
# running
# goes
# eats
# goes
# eats
# rushing
# take
# throws
# take
# throws
# peeved
# checking
# falls
# goes
# get
# goes
# get
# takes
# work
# open
# stop
# have
# open
# stop
# have
# open
# stop
# have
# goes
# opens
# takes
# go
# work
# stop
# have
# goes
# opens
# takes
# go
# work
# stop
# have
# goes
# opens
# takes
# go
# work
# stop
# have
# goes
# opens
# takes
# go
# work
# stop
# have
# goes
# opens
# takes
# go
# work
# stop
# have
# goes
# opens
# takes
# go
# work
# stop
# have
# goes
# opens
# takes
# go
# work
# stop
# have
# go
# work
# go
# work
# take
# stop
# have
# take
# stop
# have
# take
# stop
# have
# steps
# notices
# falling
# stand
# directing
# places
# removes
# stop
# removes
# stop
# walks
# picks
# places
# picks
# places
# heard
# hands
# holding
# dismissing
# fretting
# hears
# coming
# hears
# coming
# go
# work
# stop
# have
# go
# work
# go
# pull
# go
# work
# stop
# have
# go
# work
# go
# pull
# go
# work
# stop
# have
# go
# work
# go
# pull
# go
# work
# stop
# have
# go
# work
# go
# pull
# go
# work
# stop
# have
# go
# work
# go
# pull
# go
# work
# stop
# have
# go
# work
# go
# pull
# go
# work
# stop
# have
# go
# work
# go
# pull
# go
# work
# stop
# have
# go
# work
# go
# pull
# stop
# have
# tosses
# carry
# leave
# stop
# have
# tosses
# carry
# leave
# stop
# have
# tosses
# carry
# leave
# stop
# have
# tosses
# carry
# leave
# stop
# have
# tosses
# carry
# leave
# leaves
# hands
# pretends
# saying
# pretends
# saying
# hissing
# stay
# twitches
# relieved
# shot
# screen
# left
# screen
# left
# rising
# left
# screen
# left
# screen
# dropping
# screen
# left
# screen
# left
# left
# crosses
# moves
# follows
# crosses
# moves
# follows
# crosses
# moves
# follows
# walks
# listening
# rushing
# rips
# intervening
# brings
# hugs
# brings
# hugs
# turns
# walks
# turns
# walks
# arriving
# standing
# return
# gasps
# opens
# enter
# singing
# go
# work
# return
# gasps
# opens
# enter
# singing
# go
# work
# return
# gasps
# opens
# enter
# singing
# go
# work
# return
# gasps
# opens
# enter
# singing
# go
# work
# return
# gasps
# opens
# enter
# singing
# go
# work
# return
# gasps
# opens
# enter
# singing
# go
# work
# return
# gasps
# opens
# enter
# singing
# go
# work
# stop
# go
# work
# stop
# have
# stop
# have
# looking
# go
# work
# open
# go
# work
# open
# go
# work
# open
# go
# stop
# go
# work
# go
# hop
# follow
# stops
# faces
# go
# work
# go
# hop
# follow
# stops
# faces
# go
# work
# go
# hop
# follow
# stops
# faces
# go
# work
# go
# hop
# follow
# stops
# faces
# go
# work
# go
# hop
# follow
# stops
# faces
# go
# work
# go
# hop
# follow
# stops
# faces
# go
# work
# go
# hop
# follow
# stops
# faces
# whacks
# whacks
# advances
# goes
# muttering
# reaches
# knocks
# opens
# reaches
# knocks
# opens
# reaches
# knocks
# opens
# look
# turns
# has
# Looks
# calls
# mound
# has
# Looks
# calls
# mound
# has
# Looks
# calls
# mound
# has
# Looks
# calls
# mound
# says
# walks
# move
# falls
# taking
# blinks
# comes
# looking
# slips
# looks
# tightens
# jumps
# grabs
# jumps
# grabs
# jump
# reaches
# do
# jumps
# reaches
# do
# jumps
# reaches
# do
# jumps
# cheer
# bandaged
# advancing
# backs
# trips
# disappears
# backs
# turns
# walks
# turns
# walks
# looks
# calls
# looks
# calls
# looks
# moves
# goes
# wipes
# slips
# drops
# stands
# drops
# stands
# frustrated
# pulls
# going
# pulls
# going
# raises
# punches
# hits
# starts
# fighting
# show
# hits
# starts
# fighting
# show
# hits
# starts
# fighting
# show
# hits
# starts
# fighting
# show
# stop
# annoyed
# arriving
# close
# pushes
# turns
# picks
# inspect
# turns
# picks
# inspect
# turns
# picks
# inspect
# expresses
# lowers
# rushes
# lowers
# rushes
# taking
# gasp
# interrupts
# looks
# glances
# looks
# glances
# stirs
# stirs
# Raises
# soothe
# Raises
# soothe
# alarmed
# takes
# moves
# open
# hits
# soothes
# hits
# soothes
# rushing
# come
# look
# opens
# rush
# opens
# rush
# rushing
# throws
# sedates
# turns
# walks
# turns
# walks
# turns
# walks
# turns
# walks
# notices
# opens
# makes
# opens
# makes
# leads
# seen
# assed
# leads
# seen
# assed
# leads
# seen
# assed
# turn
# throws
# overturns
# moves
# throws
# overturns
# moves
# throws
# overturns
# moves
# chuckle
# goes
# notices
# looks
# walks
# rushes
# heads
# rushes
# heads
# reaches
# looks
# looks
# looks
# looks
# leaves
# hushed
# hushed
# walks
# turns
# walks
# stares
# appears
# check
# walks
# shown
# appear
# walks
# closes
# stops
# walks
# closes
# stops
# walks
# closes
# stops
# walks
# leaps
# scratches
# leaps
# scratches
# walks
# bathing
# looks
# walks
# bathing
# looks
# walks
# bathing
# looks
# turns
# see
# turns
# see
# rushing
# drops
# opens
# show
# opens
# show
# flips
# closes
# run
# puts
# puts
# lock
# start
# fighting
# lock
# start
# fighting
# lock
# start
# fighting
# bends
# picks
# bends
# picks
# rising
# curled
# hisses
# curled
# hisses
# drops
# punched
# punched
# throws
# walks
# look
# blinks
# shows
# hunting
# shows
# hunting
# panting
# panting
# rushing
# passes
# cocks
# goes
# cocks
# goes
# gives
# stay
# jumps
# meeting
# pounces
# reaches
# pins
# reverses
# ducking
# comes
# descends
# comes
# descends
# acknowledges
# pinned
# lets
# gets
# thrown
# catching
# steps
# turns
# leaving
# following
# hunting
# walks
# stops
# turns
# left
# goes
# turns
# left
# goes
# turns
# left
# goes
# grazing
# sneaks
# grazing
# sneaks
# walks
# frowns
# wander
# laugh
# notices
# nods
# notices
# nods
# steps
# steps
# sees
# begins
# swoon
# sees
# begins
# swoon
# sees
# begins
# swoon
# smiles
# distracted
# stays
# smiles
# distracted
# stays
# smiles
# distracted
# stays
# sighs
# tells
# sighs
# tells
# picks
# smiling
# picks
# smiling
# laugh
# sticks
# flips
# hops
# opens
# enter
# hops
# opens
# enter
# hops
# opens
# enter
# exits
# drops
# look
# looks
# writes
# drops
# pleads
# drops
# pleads
# enters
# drags
# tosses
# closes
# pulls
# look
# closes
# pulls
# look
# closes
# pulls
# look
# sits
# looks
# picks
# looks
# picks
# hushed
# move
# look
# move
# look
# Throws
# open
# Throws
# open
# sits
# looks
# picks
# picks
# stops
# are
# dropped
# pays
# drives
# wave
# stops
# are
# dropped
# pays
# drives
# wave
# stops
# are
# dropped
# pays
# drives
# wave
# stops
# are
# dropped
# pays
# drives
# wave
# stops
# are
# dropped
# pays
# drives
# wave
# stops
# are
# dropped
# pays
# drives
# wave
# pretends
# rushing
# covers
# turns
# covers
# picks
# cocked
# has
# cocked
# has
# faces
# waves
# opens
# rushing
# appears
# walks
# look
# presses
# begin
# dance
# look
# presses
# begin
# dance
# look
# presses
# begin
# dance
# look
# presses
# begin
# dance
# sing
# sing
# sing
# sing
# sings
# joins
# rush
# bring
# rush
# bring
# regroup
# stumbles
# stopped
# walk
# regroup
# stumbles
# stopped
# walk
# regroup
# stumbles
# stopped
# walk
# regroup
# stumbles
# stopped
# walk
# alarmed
# closes
# sees
# sees
# turns
# stops
# turns
# stops
# looks
# sits
# resting
# sits
# resting
# takes
# takes
# starts
# beating
# takes
# starts
# beating
# takes
# starts
# beating
# screams
# flees
# hangs
# takes
# starts
# beating
# takes
# starts
# beating
# takes
# starts
# beating
# pulls
# throws
# fed
# buries
# fed
# buries
# hides
# see
# standing
# wrapped
# standing
# wrapped
# runs
# hiding
# lifts
# jumps
# wraps
# suffocating
# jumps
# wraps
# suffocating
# jumps
# wraps
# suffocating
# bites
# looks
# drops
# hide
# falls
# bites
# looks
# drops
# hide
# falls
# bites
# looks
# drops
# hide
# falls
# bites
# looks
# drops
# hide
# falls
# bites
# looks
# drops
# hide
# falls
# starts
# swallowing
# starts
# swallowing
# petrified
# come
# spins
# beats
# turns
# comes
# beats
# turns
# comes
# beats
# turns
# comes
# hurries
# gives
# hurries
# gives
# points
# points
# moves
# points
# moves
# walking
# holds
# looks
# looks
# looks
# grabs
# gets
# grabs
# gets
# go
# walks
# picks
# lowers
# grabs
# looks
# picks
# lowers
# grabs
# looks
# picks
# lowers
# grabs
# looks
# picks
# lowers
# grabs
# looks
# moves
# approaching
# shows
# falls
# sees
# runs
# start
# groan
# start
# groan
# runs
# holding
# moves
# listens
# rubs
# points
# leave
# addresses
# stare
# thinks
# moves
# presses
# plays
# begin
# dance
# presses
# plays
# begin
# dance
# presses
# plays
# begin
# dance
# presses
# plays
# begin
# dance
# nears
# doing
# nears
# doing
# dance
# stops
# begin
# laugh
# begin
# laugh
# cocks
# emphasizes
# waving
# steps
# shield
# coming
# steps
# shield
# coming
# steps
# shield
# coming
# moves
# stops
# touch
# stops
# touch
# finish
# wraps
# pulls
# finish
# wraps
# pulls
# finish
# wraps
# pulls
# grabs
# walks
# grabs
# walks
# crying
# stops
# turns
# stops
# turns
# walks
# puts
# walks
# puts
# comforted
# smiles
# comforted
# smiles
# gushing
# moves
# moves
# moves
# mount
# roars
# jumps
# roars
# jumps
# turns
# walks
# came
# turns
# walks
# came
# turns
# walks
# came
# walks
# watch
# leave
# watch
# leave
# finds
# moving
# finds
# moving
# rushes
# reaches
# falls
# lifts
# drops
# lifts
# drops
# holds
# seeing
# laughs
# tries
# seeing
# laughs
# tries
# seeing
# laughs
# tries
# seen
# floating
# seen
# floating
# rush
# find
# rush
# find
# face
# surround
# face
# surround
# surrounded
# bearing
# surrounded
# bearing
# marveling
# raise
# giving
# throwing
# giving
# throwing
# roars
# looks
# flies
# roars
# looks
# flies
# roars
# looks
# flies
# falls
# goes
# helps
# keep
# running
# runs
# begin
# sink
# goes
# helps
# keep
# running
# runs
# begin
# sink
# goes
# helps
# keep
# running
# runs
# begin
# sink
# goes
# helps
# keep
# running
# runs
# begin
# sink
# goes
# helps
# keep
# running
# runs
# begin
# sink
# goes
# helps
# keep
# running
# runs
# begin
# sink
# goes
# helps
# keep
# running
# runs
# begin
# sink
# surround
# leap
# screaming
# surround
# leap
# screaming
# surround
# leap
# screaming
# snuggles
# tries
# pick
# let
# tries
# pick
# let
# tries
# pick
# let
# put
# rises
# rumbles
# responds
# rises
# rumbles
# responds
# rises
# rumbles
# responds
# stop
# dancing
# stop
# dancing
# cutting
# cut
# arriving
# strikes
# knocking
# strikes
# knocking
# falls
# gets
# goes
# falls
# gets
# goes
# falls
# gets
# goes
# turns
# face
# turns
# face
# turns
# tries
# giving
# pounds
# tries
# giving
# pounds
# tries
# giving
# pounds
# picks
# pounds
# listens
# picks
# pounds
# listens
# picks
# pounds
# listens
# applauds
# sing
# sing
# sing
# sing
# dance
# sings
# joins
# bringing
# shut
# walk
# walks
# left
# looking
# left
# looking
# rushing
# rushing
# drives
# rushes
# begins
# daydream
# begins
# daydream
# rushing
# hop
# move
# approaches
# opens
# reads
# hop
# move
# approaches
# opens
# reads
# hop
# move
# approaches
# opens
# reads
# hop
# move
# approaches
# opens
# reads
# hop
# move
# approaches
# opens
# reads
# falls
# reads
# checks
# sniffs
# falls
# reads
# checks
# sniffs
# falls
# reads
# checks
# sniffs
# falls
# reads
# checks
# sniffs
# man
# close
# bow
# close
# bow
# raises
# left
# raises
# left
# extends
# carry
# extends
# carry
# stops
# leave
# stops
# leave
# hands
# walks
# shows
# hands
# walks
# shows
# hands
# walks
# shows
# combusted
# consoling
# looks
# start
# close
# go
# resumes
# closes
# gestures
# dressed
# stand
# dressed
# stand
# move
# throws
# rushing
# pours
# see
# pours
# see
# walks
# bow
# approach
# followed
# approach
# followed
# takes
# hits
# dressed
# hits
# dressed
# carrying
# calling
# indicates
# rushing
# hangs
# hangs
# tied
# produces
# replaces
# returns
# leads
# leaves
# exits
# drop
# lift
# leave
# drop
# lift
# leave
# drop
# lift
# leave
# stop
# turn
# stop
# turn
# turn
# leave
# turn
# leave
# looks
# struggles
# get
# get
# struggles
# get
# get
# struggles
# get
# get
# approaches
# displays
# showing
# produces
# showing
# produces
# shows
# shows
# collects
# shows
# collects
# shows
# trapped
# shows
# trapped
# shows
# exploding
# shows
# exploding
# shows
# closes
# shows
# closes
# heard
# follow
# release
# heard
# follow
# release
# heard
# follow
# release
# waves
# leave
# watches
# leave
# watches
# leave
# imitating
# moves
# hums
# moves
# hums
# slaps
# lets
# slaps
# lets
# cover
# leaves
# laughing
# walk
# leaves
# laughing
# walk
# leaves
# laughing
# walk
# cover
# leaves
# leaves
# unveil
# muscled
# unveil
# muscled
# strolling
# looks
# see
# says
# looks
# see
# says
# looks
# see
# says
# taps
# turns
# walks
# turns
# walks
# applauds
# laughs
# laughs
# laughs
# fanfare
# applauds
# steps
# fanfare
# applauds
# steps
# fanfare
# applauds
# steps
# shown
# mentioned
# shown
# mentioned
# opens
# applauds
# grabs
# picks
# hands
# opens
# see
# look
# grins
# walks
# look
# grins
# walks
# look
# grins
# walks
# prepares
# turn
# walk
# turn
# walk
# entering
# wearing
# entering
# wearing
# look
# whispering
# hoping
# whispering
# hoping
# walks
# sees
# rushes
# does
# waking
# goes
# appears
# sits
# appears
# sits
# brings
# drawn
# brings
# drawn
# stunned
# turns
# walks
# follows
# shows
# closes
# turns
# walks
# follows
# shows
# closes
# turns
# walks
# follows
# shows
# closes
# turns
# walks
# follows
# shows
# closes
# turns
# walks
# follows
# shows
# closes
# turns
# gasp
# rips
# leaving
# rips
# leaving
# throw
# drags
# begins
# stone
# throw
# drags
# begins
# stone
# throw
# drags
# begins
# stone
# throw
# drags
# begins
# stone
# struggling
# keeping
# throws
# deposits
# setting
# rides
# deposits
# setting
# rides
# deposits
# setting
# rides
# sits
# listens
# sits
# listens
# turns
# opens
# enter
# turns
# opens
# enter
# turns
# opens
# enter
# takes
# stands
# dressed
# does
# takes
# stands
# dressed
# does
# takes
# stands
# dressed
# does
# takes
# stands
# dressed
# does
# performs
# gets
# go
# gets
# go
# returns
# mixes
# writes
# mixes
# writes
# explains
# set
# boils
# set
# boils
# looks
# approve
# chases
# floating
# play
# appears
# play
# appears
# comes
# looks
# runs
# hops
# closes
# stones
# closes
# stones
# shielding
# hold
# drop
# smiles
# throws
# drop
# smiles
# throws
# drop
# smiles
# throws
# repaired
# leave
# enters
# follows
# close
# follows
# close
# resigned
# points
# turns
# sits
# turns
# sits
# lowering
# laughs
# stands
# pushes
# laughs
# stands
# pushes
# laughs
# stands
# pushes
# removes
# reads
# throws
# places
# begins
# calibrate
# begins
# calibrate
# flips
# flips
# chooses
# hits
# removes
# laugh
# sees
# blinks
# enter
# runs
# falls
# enter
# runs
# falls
# enter
# runs
# falls
# wearing
# rubs
# hits
# falls
# gets
# falls
# gets
# laughs
# takes
# shoots
# takes
# shoots
# looks
# runs
# wrapped
# opens
# wrapped
# opens
# walks
# looks
# walks
# looks
# ignoring
# cuddles
# teasing
# reaches
# pulls
# starts
# play
# reaches
# pulls
# starts
# play
# reaches
# pulls
# starts
# play
# reaches
# pulls
# starts
# play
# pulls
# see
# think
# sits
# seething
# throws
# puts
# seeing
# look
# seeing
# look
# takes
# starts
# stapling
# takes
# starts
# stapling
# takes
# starts
# stapling
# run
# study
# laugh
# study
# laugh
# study
# laugh
# study
# laugh
# directs
# seen
# stops
# directs
# seen
# stops
# directs
# seen
# stops
# pops
# grins
# leave
# appears
# signals
# gets
# writes
# rings
# leaves
# walk
# leaves
# walk
# asserting
# leave
# pulls
# driven
# pulls
# driven
# enter
# rushes
# hurries
# drops
# walk
# hurries
# drops
# walk
# hurries
# drops
# walk
# follows
# giggle
# giggle
# turns
# knocks
# walk
# disappointed
# entering
# face
# leaves
# enters
# leaves
# enters
# looks
# jump
# pulls
# looks
# jump
# pulls
# looks
# jump
# pulls
# loosened
# sets
# becomes
# grows
# becomes
# grows
# laughs
# scream
# pulls
# resets
# laughs
# scream
# pulls
# resets
# laughs
# scream
# pulls
# resets
# laughs
# scream
# pulls
# resets
# leaves
# trembling
# keeps
# trembling
# keeps
# quiet
# stops
# quiet
# stops
# sniffles
# stop
# approach
# pointing
# hurt
# starts
# crying
# cradles
# starts
# crying
# cradles
# starts
# crying
# cradles
# exit
# rolls
# closes
# picks
# doubting
# nodding
# turns
# taps
# rattled
# telling
# Comes
# await
# Comes
# await
# walks
# joins
# leave
# begins
# removed
# 's
# removed
# 's
# holds
# gasps
# pissed
# holds
# gasps
# pissed
# holds
# gasps
# pissed
# looks
# turn
# face
# turn
# face
# begins
# move
# begins
# move
# punches
# reaches
# plays
# reaches
# plays
# singing
# flash
# sees
# reverses
# transforms
# tearing
# revealing
# screams
# transforms
# tearing
# revealing
# screams
# transforms
# tearing
# revealing
# screams
# transforms
# tearing
# revealing
# screams
# falls
# roars
# flies
# hovers
# scream
# dive
# roars
# flies
# hovers
# scream
# dive
# roars
# flies
# hovers
# scream
# dive
# roars
# flies
# hovers
# scream
# dive
# roars
# flies
# hovers
# scream
# dive
# pressing
# tries
# help
# tries
# help
# lands
# breaking
# lands
# breaking
# runs
# reaching
# gets
# knocks
# gets
# knocks
# presses
# resumes
# grips
# roaring
# grips
# roaring
# opens
# appear
# drops
# leave
# walks
# looks
# opens
# appear
# drops
# leave
# walks
# looks
# opens
# appear
# drops
# leave
# walks
# looks
# opens
# appear
# drops
# leave
# walks
# looks
# opens
# appear
# drops
# leave
# walks
# looks
# opens
# appear
# drops
# leave
# walks
# looks
# sits
# walks
# man
# walk
# do
# start
# rising
# walk
# do
# start
# rising
# walk
# do
# start
# rising
# walk
# do
# start
# rising
# begins
# sing
# begins
# sing
# fades
# takes
# show
# takes
# show
# gets
# pulls
# gets
# pulls
# plays
# plays
# sing
# gets
# walks
# gets
# walks
# begins
# lower
# begins
# lower
# moves
# squats
# begins
# squats
# begins
# begin
# laugh
# begin
# laugh
# heard
# looking
# begins
# walk
# realizes
# used
# begins
# walk
# realizes
# used
# begins
# walk
# realizes
# used
# begins
# walk
# realizes
# used
# goes
# roasting
# goes
# roasting
# hears
# zips
# hears
# zips
# running
# urging
# walk
# move
# looks
# close
# tries
# speak
# tries
# speak
# eructing
# trying
# keep
# trying
# keep
# opens
# goes
# reappears
# follows
# goes
# reappears
# follows
# goes
# reappears
# follows
# heard
# cocks
# move
# turns
# flashes
# turns
# flashes
# annoyed
# intervening
# shaking
# looks
# shaking
# looks
# stares
# walks
# walk
# shows
# stare
# shows
# stare
# raises
# turns
# look
# turns
# look
# eructing
# look
# raises
# wondering
# knocks
# opens
# screams
# opens
# screams
# falls
# gets
# falls
# gets
# stay
# looking
# stay
# looking
# turns
# opens
# comes
# opens
# comes
# clears
# rattling
# heard
# clears
# rattling
# heard
# clears
# rattling
# heard
# put
# sees
# help
# sees
# help
# rushes
# sitting
# turns
# smacks
# laughing
# soothing
# show
# looking
# show
# looking
# eructing
# enters
# hangs
# enters
# hangs
# reaches
# keeps
# teasing
# reaches
# keeps
# teasing
# reaches
# keeps
# teasing
# hands
# barges
# takes
# reading
# walks
# speaks
# walks
# speaks
# begins
# disperse
# begins
# disperse
# finds
# falls
# make
# sticks
# make
# sticks
# scratches
# leave
# closes
# walking
# sees
# 's
# sees
# 's
# stroke
# holds
# imitates
# stops
# sticks
# draws
# reacts
# goes
# sticks
# draws
# reacts
# goes
# sticks
# draws
# reacts
# goes
# sticks
# draws
# reacts
# goes
# adds
# stop
# turns
# face
# stop
# turns
# face
# stop
# turns
# face
# snap
# hands
# gets
# trips
# knocking
# trips
# knocking
# closes
# laugh
# gushing
# shot
# strikes
# whimpers
# drops
# shot
# strikes
# whimpers
# drops
# shot
# strikes
# whimpers
# drops
# shot
# strikes
# whimpers
# drops
# gets
# moves
# growling
# gets
# moves
# growling
# gets
# moves
# growling
# close
# flying
# close
# flying
# starts
# pumping
# crouch
# starts
# pumping
# crouch
# starts
# pumping
# crouch
# end
# walks
# end
# walks
# picks
# says
# picks
# says
# pumps
# getting
# sitting
# starts
# writing
# starts
# writing
# raises
# waves
# raises
# waves
# start
# fight
# start
# fight
# like
# like
# like
# defeated
# responds
# supports
# responds
# supports
# shows
# respond
# opens
# appear
# opens
# appear
# touched
# exulting
# pissed
# gives
# fitting
# climb
# closes
# speeds
# look
# closes
# speeds
# look
# closes
# speeds
# look
# appears
# appears
# appears
# appears
# enters
# wearing
# carrying
# enters
# wearing
# carrying
# enters
# wearing
# carrying
# trips
# crashes
# heard
# trips
# crashes
# heard
# trips
# crashes
# heard
# gets
# rubbing
# gets
# rubbing
# brings
# opens
# reads
# opens
# reads
# opens
# start
# walking
# start
# walking
# trips
# falls
# gets
# face
# heard
# grin
# trips
# falls
# gets
# face
# heard
# grin
# trips
# falls
# gets
# face
# heard
# grin
# trips
# falls
# gets
# face
# heard
# grin
# trips
# falls
# gets
# face
# heard
# grin
# trips
# falls
# gets
# face
# heard
# grin
# snatches
# rushing
# thrusts
# arm
# thrusts
# arm
# hangs
# eructing
# whispering
# goes
# turns
# hoot
# cheer
# correcting
# stay
# stop
# gets
# whispers
# brings
# pointing
# wearing
# looks
# drops
# rushes
# drops
# rushes
# rushes
# growling
# rushes
# growling
# mauls
# tumbles
# mauls
# tumbles
# looks
# raises
# rejoice
# start
# carrying
# start
# carrying
# carry
# looking
# turns
# enter
# turns
# enter
# laughs
# arriving
# running
# arriving
# running
# closes
# pounding
# facing
# backs
# moves
# rushes
# runs
# backs
# moves
# rushes
# runs
# backs
# moves
# rushes
# runs
# backs
# moves
# rushes
# runs
# takes
# watch
# disappears
# takes
# watch
# disappears
# takes
# watch
# disappears
# resigned
# begins
# surround
# begins
# surround
# reaching
# walks
# wearing
# pulls
# drops
# pulls
# pulls
# drops
# pulls
# pulls
# drops
# pulls
# crashes
# ends
# crashes
# ends
# stares
# start
# laughing
# stares
# start
# laughing
# stares
# start
# laughing
# continues
# raises
# stirring
# points
# picks
# begins
# lost
# looking
# picks
# begins
# lost
# looking
# picks
# begins
# lost
# looking
# picks
# begins
# lost
# looking
# sets
# flips
# hushed
# scans
# appears
# raises
# cautioning
# look
# cuts
# passing
# leafs
# approaches
# leafs
# approaches
# revs
# jumps
# jumps
# drops
# leafing
# jumps
# flips
# puts
# calm
# flips
# puts
# calm
# flips
# puts
# calm
# blocks
# flips
# Tweek
# flips
# Tweek
# twitches
# walk
# pleased
# walk
# pleased
# runs
# laughs
# catches
# laughs
# catches
# holding
# sniffs
# laughing
# trying
# regain
# trying
# regain
# opens
# get
# chews
# opens
# get
# chews
# opens
# get
# chews
# closes
# continues
# chewing
# closes
# continues
# chewing
# closes
# continues
# chewing
# opens
# follow
# shows
# walk
# arrive
# leave
# arrive
# leave
# stand
# waiting
# stand
# waiting
# walks
# looks
# opens
# watches
# demonstrates
# watches
# demonstrates
# falls
# turns
# walk
# turns
# walk
# pops
# shuts
# hushed
# knocks
# gets
# stands
# plays
# gets
# stands
# plays
# gets
# stands
# plays
# listens
# sits
# resume
# eating
# Tweek
# sits
# resume
# eating
# Tweek
# sits
# resume
# eating
# Tweek
# sits
# resume
# eating
# Tweek
# look
# starts
# banging
# look
# starts
# banging
# look
# starts
# banging
# resume
# eating
# resume
# eating
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# flips
# begins
# closing
# begins
# closing
# shuts
# holds
# makes
# picks
# shuts
# holds
# makes
# picks
# shuts
# holds
# makes
# picks
# shuts
# holds
# makes
# picks
# waves
# opens
# sees
# opens
# sees
# trying
# regain
# trying
# regain
# rising
# opens
# gets
# starts
# chewing
# opens
# gets
# starts
# chewing
# opens
# gets
# starts
# chewing
# opens
# gets
# starts
# chewing
# resumes
# chewing
# resumes
# chewing
# covers
# laugh
# jumps
# start
# fighting
# join
# leaving
# looking
# jumps
# start
# fighting
# join
# leaving
# looking
# jumps
# start
# fighting
# join
# leaving
# looking
# jumps
# start
# fighting
# join
# leaving
# looking
# jumps
# start
# fighting
# join
# leaving
# looking
# jumps
# start
# fighting
# join
# leaving
# looking
# stands
# equating
# stands
# equating
# take
# stands
# listing
# take
# stands
# listing
# take
# stands
# listing
# crosses
# circles
# raises
# circles
# raises
# look
# hears
# calling
# hears
# calling
# remembers
# mumbling
# pulls
# dreams
# remembers
# mumbling
# pulls
# dreams
# remembers
# mumbling
# pulls
# dreams
# remembers
# mumbling
# pulls
# dreams
# waves
# Cut
# opening
# waves
# Cut
# opening
# waves
# Cut
# opening
# calls
# sounds
# explodes
# sounds
# explodes
# tries
# land
# falls
# thrown
# tries
# land
# falls
# thrown
# tries
# land
# falls
# thrown
# tries
# land
# falls
# thrown
# comes
# stands
# are
# comes
# stands
# are
# comes
# stands
# are
# looks
# walks
# noticing
# puts
# hurries
# joins
# meet
# look
# happens
# look
# happens
# turns
# let
# Tweek
# sighs
# approaches
# faking
# part
# rings
# sends
# rings
# sends
# gets
# does
# punches
# falls
# does
# punches
# falls
# does
# punches
# falls
# gets
# prancing
# lands
# lands
# groans
# lands
# groans
# does
# flips
# comes
# speaks
# comes
# speaks
# stops
# pull
# pats
# stops
# pull
# pats
# stops
# pull
# pats
# plants
# pushing
# turns
# back
# turns
# back
# bumps
# hits
# bumps
# hits
# plants
# twisting
# turning
# twisting
# turning
# laughing
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# writes
# love
# gets
# loses
# comes
# explodes
# screams
# manages
# write
# sinks
# calls
# looks
# reaches
# find
# reaches
# find
# begins
# bawling
# begins
# bawling
# holds
# saying
# holds
# saying
# including
# holds
# saying
# holds
# saying
# including
# holds
# saying
# holds
# saying
# holds
# saying
# holds
# saying
# looks
# gets
# goes
# gets
# goes
# threatening
# fill
# saw
# threatening
# fill
# saw
# threatening
# fill
# saw
# draws
# rings
# draws
# rings
# begin
# file
# begin
# file
# close
# holding
# adjusts
# flips
# leaves
# goes
# turns
# lies
# pulled
# leaves
# goes
# turns
# lies
# pulled
# leaves
# goes
# turns
# lies
# pulled
# leaves
# goes
# turns
# lies
# pulled
# leaves
# goes
# turns
# lies
# pulled
# sits
# lie
# head
# lie
# head
# stuck
# punches
# takes
# hands
# goes
# hands
# goes
# gets
# pops
# tackles
# fearing
# cheer
# pops
# tackles
# fearing
# cheer
# pops
# tackles
# fearing
# cheer
# pops
# tackles
# fearing
# cheer
# sits
# opens
# pour
# opens
# pour
# stands
# walks
# stands
# walks
# knock
# hangs
# knock
# hangs
# tumble
# falls
# tumbles
# tumble
# falls
# tumbles
# tumble
# falls
# tumbles
# gets
# spins
# thrown
# ends
# fly
# gets
# spins
# thrown
# ends
# fly
# gets
# spins
# thrown
# ends
# fly
# gets
# spins
# thrown
# ends
# fly
# gets
# spins
# thrown
# ends
# fly
# goes
# plucks
# goes
# plucks
# shrug
# settles
# leaves
# takes
# leaves
# takes
# leaves
# enters
# leaves
# enters
# leaves
# holds
# leads
# follow
# let
# recovering
# leads
# follow
# let
# recovering
# leads
# follow
# let
# recovering
# leads
# follow
# let
# recovering
# flips
# turns
# turns
# starts
# leaving
# starts
# leaving
# raises
# says
# reaches
# drops
# shows
# puts
# gets
# puts
# gets
# sitting
# entering
# moves
# rests
# comforts
# hides
# begins
# sobbing
# hides
# begins
# sobbing
# hides
# begins
# sobbing
# puts
# goes
# pulls
# tosses
# reaches
# tosses
# reaches
# tosses
# approaches
# drops
# walks
# drops
# walks
# looks
# picks
# presses
# picks
# presses
# rushes
# grab
# rushes
# grab
# laughs
# gaveling
# staring
# beaks
# composes
# begins
# goes
# takes
# twirls
# takes
# twirls
# walks
# thinks
# raises
# gone
# raises
# gone
# smiles
# starts
# grates
# starts
# grates
# wincing
# turns
# face
# turns
# face
# scratching
# wincing
# turns
# slams
# shut
# slams
# shut
# rings
# rides
# rings
# rides
# sunning
# come
# cater
# come
# cater
# jumps
# sung
# jumps
# sung
# Call
# sits
# tilts
# rubs
# sits
# hops
# gets
# turns
# see
# gets
# turns
# see
# gets
# turns
# see
# admonishing
# whispers
# approaches
# leaves
# runs
# enter
# hide
# rises
# handed
# nods
# serves
# nods
# serves
# lowers
# look
# lowers
# look
# approaches
# has
# rises
# goes
# watches
# go
# rises
# goes
# watches
# go
# rises
# goes
# watches
# go
# rises
# goes
# watches
# go
# arrives
# annoyed
# looks
# annoyed
# looks
# rises
# approaches
# pointing
# pounds
# pointing
# look
# said
# look
# said
# make
# leave
# make
# leave
# sits
# sips
# lowers
# sips
# lowers
# fall
# reads
# enter
# pulls
# puts
# sticks
# simulate
# puts
# pulls
# puts
# sticks
# simulate
# puts
# pulls
# puts
# sticks
# simulate
# puts
# pulls
# puts
# sticks
# simulate
# puts
# pulls
# puts
# sticks
# simulate
# puts
# rushes
# snapping
# rushes
# snapping
# walks
# shows
# hands
# walks
# generating
# turns
# rev
# hands
# walks
# generating
# turns
# rev
# hands
# walks
# generating
# turns
# rev
# hands
# walks
# generating
# turns
# rev
# hands
# walks
# generating
# turns
# rev
# pulls
# chopped
# pulls
# chopped
# looks
# seated
# playing
# seated
# playing
# rush
# leave
# rush
# leave
# follows
# look
# follows
# look
# see
# rushes
# jumps
# stands
# jumps
# stands
# bursting
# faces
# stands
# listening
# seen
# get
# rises
# rising
# approaches
# leave
# leaves
# leave
# passing
# walks
# tied
# standing
# tied
# standing
# whips
# tosses
# aims
# hanging
# tosses
# aims
# hanging
# tosses
# aims
# hanging
# performs
# tosses
# knocks
# tosses
# knocks
# opens
# looks
# turns
# drops
# turns
# drops
# begging
# exits
# closes
# exits
# closes
# begins
# rap
# begins
# rap
# starts
# rubbing
# starts
# rubbing
# looks
# runs
# enters
# drops
# rub
# drops
# rub
# gets
# leaves
# gets
# leaves
# approaches
# punches
# leaves
# fallen
# punches
# leaves
# fallen
# punches
# leaves
# fallen
# punches
# sending
# punches
# sending
# takes
# rises
# goes
# rises
# goes
# strains
# open
# fails
# strains
# open
# fails
# strains
# open
# fails
# goes
# props
# hops
# walks
# pining
# goes
# props
# hops
# walks
# pining
# goes
# props
# hops
# walks
# pining
# goes
# props
# hops
# walks
# pining
# goes
# props
# hops
# walks
# pining
# turns
# sees
# grabs
# reads
# turns
# sees
# grabs
# reads
# turns
# sees
# grabs
# reads
# turns
# sees
# grabs
# reads
# hops
# moves
# sits
# grabs
# hops
# moves
# sits
# grabs
# hops
# moves
# sits
# grabs
# hops
# moves
# sits
# grabs
# picks
# find
# picks
# find
# hangs
# picks
# hangs
# picks
# hangs
# picks
# enters
# pulls
# blinding
# enters
# pulls
# blinding
# enters
# pulls
# blinding
# leaves
# picks
# leaves
# picks
# hangs
# puts
# resumes
# hangs
# puts
# resumes
# hangs
# puts
# resumes
# echoing
# comes
# tosses
# changes
# comes
# tosses
# changes
# comes
# tosses
# changes
# answers
# looks
# answers
# looks
# appears
# studies
# studies
# enters
# pulls
# drops
# enters
# pulls
# drops
# enters
# pulls
# drops
# takes
# walk
# pass
# looking
# takes
# walk
# pass
# looking
# takes
# walk
# pass
# looking
# takes
# walk
# pass
# looking
# follows
# watches
# overtakes
# lays
# watches
# overtakes
# lays
# watches
# overtakes
# lays
# meows
# does
# meows
# does
# continues
# meowing
# rolls
# continues
# meowing
# rolls
# continues
# meowing
# rolls
# moves
# relax
# rubbing
# relax
# rubbing
# tries
# kiss
# tries
# kiss
# kisses
# intrudes
# kisses
# intrudes
# pulls
# tosses
# snatches
# sends
# snatches
# sends
# leave
# rises
# thinks
# walks
# goes
# opens
# starts
# looking
# goes
# opens
# starts
# looking
# goes
# opens
# starts
# looking
# goes
# opens
# starts
# looking
# pulls
# pours
# pulls
# pours
# longing
# jumps
# knocking
# longing
# jumps
# knocking
# longing
# jumps
# knocking
# putting
# reaches
# kiss
# reaches
# kiss
# holding
# draws
# lock
# goes
# stands
# goes
# stands
# runs
# gives
# runs
# catches
# grabs
# kicks
# closing
# reaches
# runs
# gives
# runs
# catches
# grabs
# kicks
# closing
# reaches
# runs
# gives
# runs
# catches
# grabs
# kicks
# closing
# reaches
# runs
# gives
# runs
# catches
# grabs
# kicks
# closing
# reaches
# runs
# gives
# runs
# catches
# grabs
# kicks
# closing
# reaches
# runs
# gives
# runs
# catches
# grabs
# kicks
# closing
# reaches
# runs
# gives
# runs
# catches
# grabs
# kicks
# closing
# reaches
# runs
# gives
# runs
# catches
# grabs
# kicks
# closing
# reaches
# shocked
# banging
# starts
# banging
# meowing
# starts
# banging
# meowing
# starts
# banging
# meowing
# sees
# walks
# sees
# walks
# dons
# shades
# doffs
# sees
# rubbing
# walks
# doffs
# sees
# rubbing
# walks
# doffs
# sees
# rubbing
# walks
# doffs
# sees
# rubbing
# walks
# banging
# walks
# sets
# walks
# sets
# jumps
# ends
# opens
# takes
# opens
# takes
# moves
# answer
# moves
# answer
# opens
# come
# opens
# come
# carrying
# carrying
# walks
# faking
# opens
# walks
# hold
# finds
# hold
# finds
# turns
# defeated
# gives
# turns
# defeated
# gives
# turns
# defeated
# gives
# pulls
# enters
# groans
# hits
# pulls
# enters
# groans
# hits
# pulls
# enters
# groans
# hits
# pulls
# enters
# groans
# hits
# sits
# dances
# looks
# see
# coming
# looks
# see
# coming
# looks
# see
# coming
# looks
# make
# 's
# jumps
# parked
# runs
# parked
# looks
# make
# 's
# jumps
# parked
# runs
# parked
# looks
# make
# 's
# jumps
# parked
# runs
# parked
# looks
# make
# 's
# jumps
# parked
# runs
# parked
# looks
# make
# 's
# jumps
# parked
# runs
# parked
# looks
# make
# 's
# jumps
# parked
# runs
# parked
# looks
# make
# 's
# jumps
# parked
# runs
# parked
# walks
# pulls
# act
# lets
# go
# hits
# pulls
# act
# lets
# go
# hits
# pulls
# act
# lets
# go
# hits
# pulls
# act
# lets
# go
# hits
# pulls
# act
# lets
# go
# hits
# turns
# walk
# stops
# watch
# picks
# get
# turns
# walk
# stops
# watch
# picks
# get
# turns
# walk
# stops
# watch
# picks
# get
# turns
# walk
# stops
# watch
# picks
# get
# turns
# walk
# stops
# watch
# picks
# get
# turns
# walk
# stops
# watch
# picks
# get
# keeps
# looking
# keeps
# looking
# enters
# looks
# hops
# moves
# hands
# takes
# moves
# hands
# takes
# moves
# hands
# takes
# directs
# appears
# looks
# hangs
# looks
# tiring
# take
# leave
# take
# leave
# shows
# waiting
# pounces
# smothers
# shows
# waiting
# pounces
# smothers
# shows
# waiting
# pounces
# smothers
# shows
# waiting
# pounces
# smothers
# squeezes
# rolls
# jumps
# smothers
# rolls
# jumps
# smothers
# rolls
# jumps
# smothers
# makes
# collapses
# seeing
# move
# leaves
# seeing
# move
# leaves
# seeing
# move
# leaves
# plays
# worked
# plays
# worked
# hides
# softens
# speaks
# recording
# walks
# sits
# walks
# sits
# bumps
# answer
# sitting
# walks
# sticks
# jump
# answer
# sitting
# walks
# sticks
# jump
# answer
# sitting
# walks
# sticks
# jump
# answer
# sitting
# walks
# sticks
# jump
# answer
# sitting
# walks
# sticks
# jump
# pushes
# moves
# looks
# forsaken
# draws
# looks
# forsaken
# draws
# looks
# forsaken
# draws
# drives
# continues
# crying
# continues
# crying
# seem
# realize
# seem
# realize
# cries
# pours
# cries
# pours
# softens
# come
# make
# turns
# come
# come
# make
# turns
# come
# come
# make
# turns
# come
# come
# make
# turns
# come
# lies
# playing
# lies
# playing
# goes
# find
# goes
# find
# reaches
# Stands
# makes
# Stands
# makes
# moves
# sees
# rushes
# gasps
# buried
# arranged
# read
# gasps
# buried
# arranged
# read
# gasps
# buried
# arranged
# read
# gasps
# buried
# arranged
# read
# faces
# opens
# shocked
# see
# opens
# shocked
# see
# opens
# shocked
# see
# gets
# holds
# gets
# holds
# points
# goes
# follow
# points
# goes
# follow
# points
# goes
# follow
# opens
# find
# waiting
# opens
# find
# waiting
# opens
# find
# waiting
# throws
# jump
# appear
# go
# close
# go
# close
# hide
# holds
# walks
# Crashes
# falls
# Crashes
# falls
# raps
# watches
# perform
# joins
# watches
# perform
# joins
# watches
# perform
# joins
# roll
# leads
# scurries
# opens
# enters
# tugging
# tugging
# closes
# looks
# looks
# tries
# open
# locked
# turns
# face
# closes
# looks
# looks
# tries
# open
# locked
# turns
# face
# closes
# looks
# looks
# tries
# open
# locked
# turns
# face
# closes
# looks
# looks
# tries
# open
# locked
# turns
# face
# closes
# looks
# looks
# tries
# open
# locked
# turns
# face
# closes
# looks
# looks
# tries
# open
# locked
# turns
# face
# closes
# looks
# looks
# tries
# open
# locked
# turns
# face
# closes
# looks
# looks
# tries
# open
# locked
# turns
# face
# bows
# looks
# tries
# opening
# tries
# opening
# jerks
# pulling
# jerks
# pulling
# walks
# stand
# walks
# stand
# offers
# takes
# takes
# dancing
# turn
# fall
# gets
# fall
# gets
# looks
# walks
# annoyed
# covers
# annoyed
# covers
# looks
# reach
# look
# reach
# look
# leafing
# pulls
# checks
# pulls
# checks
# hopping
# walks
# turns
# walks
# turns
# walks
# disrobes
# jumps
# disrobes
# jumps
# disrobes
# jumps
# disrobes
# jumps
# splash
# strokes
# look
# alerts
# strokes
# look
# alerts
# strokes
# look
# alerts
# looks
# go
# pauses
# go
# pauses
# brushes
# sniffs
# brushes
# sniffs
# picks
# lights
# sets
# picks
# lights
# sets
# picks
# lights
# sets
# raises
# rises
# walks
# rises
# walks
# crawls
# know
# ends
# staring
# ends
# staring
# wait
# make
# wait
# make
# begins
# looks
# appears
# pulls
# resumes
# viewing
# interrupted
# resumes
# viewing
# interrupted
# resumes
# viewing
# interrupted
# points
# coming
# runs
# makes
# stopping
# rings
# wait
# makes
# stopping
# rings
# wait
# makes
# stopping
# rings
# wait
# makes
# stopping
# rings
# wait
# lowers
# closes
# flashing
# walk
# buttoning
# tying
# turns
# go
# turns
# go
# looks
# goes
# waves
# closes
# waves
# closes
# shrugs
# starts
# falls
# lowers
# starts
# falls
# lowers
# starts
# falls
# lowers
# raise
# disperse
# walks
# pats
# subdued
# rolls
# waiting
# hops
# starts
# switching
# hops
# starts
# switching
# hops
# starts
# switching
# annoyed
# shown
# heard
# coming
# heard
# coming
# speaks
# hops
# walks
# looks
# sees
# hops
# walks
# looks
# sees
# hops
# walks
# looks
# sees
# hops
# walks
# looks
# sees
# runs
# looking
# sits
# looks
# sensing
# hushed
# hushed
# looks
# make
# listening
# looks
# make
# listening
# looks
# make
# listening
# jumps
# rushes
# sees
# hear
# sees
# falls
# walks
# laugh
# drops
# laugh
# drops
# walks
# follow
# walks
# follow
# Shooting
# opens
# hurry
# opens
# hurry
# moved
# readies
# moved
# readies
# presses
# runs
# walk
# approaches
# walk
# approaches
# rushes
# finds
# swaying
# grows
# rushes
# gets
# walks
# watches
# go
# turns
# gets
# walks
# watches
# go
# turns
# gets
# walks
# watches
# go
# turns
# gets
# walks
# watches
# go
# turns
# gets
# walks
# watches
# go
# turns
# gets
# drops
# faints
# looks
# rouse
# gets
# drops
# faints
# looks
# rouse
# gets
# drops
# faints
# looks
# rouse
# gets
# drops
# faints
# looks
# rouse
# gets
# drops
# faints
# looks
# rouse
# panicking
# slaps
# grabs
# slaps
# grabs
# leads
# walks
# wearing
# moves
# standing
# wearing
# moves
# standing
# wearing
# moves
# standing
# filming
# cuing
# filming
# cuing
# removing
# turns
# listens
# turns
# listens
# hauls
# reads
# hauls
# reads
# holds
# throws
# moves
# walks
# Shooting
# heard
# hit
# die
# Shooting
# heard
# hit
# die
# Shooting
# heard
# hit
# die
# Shooting
# heard
# hit
# die
# aimed
# hops
# moves
# ties
# hops
# moves
# ties
# hops
# moves
# ties
# hands
# pulls
# releases
# attached
# lands
# moves
# sips
# releases
# attached
# lands
# moves
# sips
# releases
# attached
# lands
# moves
# sips
# releases
# attached
# lands
# moves
# sips
# releases
# attached
# lands
# moves
# sips
# pulls
# help
# hook
# help
# hook
# pushes
# slides
# bounces
# slides
# bounces
# runs
# take
# hands
# inspects
# hands
# inspects
# walks
# hushed
# stops
# turn
# stare
# gasps
# lifts
# turn
# stare
# gasps
# lifts
# turn
# stare
# gasps
# lifts
# turn
# stare
# gasps
# lifts
# pulls
# looking
# begin
# answer
# begin
# answer
# points
# spoke
# points
# spoke
# resumes
# goes
# do
# resumes
# goes
# do
# resumes
# goes
# do
# resumes
# walks
# runs
# waves
# runs
# waves
# holds
# runs
# address
# waves
# runs
# address
# waves
# runs
# address
# waves
# hits
# bounces
# crush
# join
# hits
# bounces
# crush
# join
# hits
# bounces
# crush
# join
# hits
# bounces
# crush
# join
# joins
# rushes
# leaving
# rushes
# leaving
# walks
# shows
# goes
# leaving
# goes
# leaving
# follows
# wait
# follows
# wait
# have
# hops
# heads
# takes
# takes
# comes
# turns
# face
# turns
# face
# takes
# brakes
# stop
# walking
# brakes
# stop
# walking
# brakes
# stop
# walking
# turns
# left
# walks
# turns
# left
# walks
# turns
# left
# walks
# leave
# drives
# dressed
# drives
# dressed
# arrives
# hides
# points
# drags
# leave
# drags
# leave
# writes
# pulls
# made
# pulls
# made
# doffs
# hops
# sees
# walk
# doffs
# hops
# sees
# walk
# doffs
# hops
# sees
# walk
# doffs
# hops
# sees
# walk
# displays
# displays
# displays
# enter
# take
# enter
# take
# raise
# wear
# raise
# wear
# does
# spots
# returns
# does
# spots
# returns
# does
# spots
# returns
# places
# leaves
# locks
# leaves
# locks
# notices
# done
# notices
# done
# leave
# come
# leave
# come
# moves
# brings
# lowers
# strikes
# produce
# raises
# walks
# lowers
# strikes
# produce
# raises
# walks
# lowers
# strikes
# produce
# raises
# walks
# lowers
# strikes
# produce
# raises
# walks
# lowers
# strikes
# produce
# raises
# walks
# lowers
# strikes
# raises
# stumbles
# crying
# lowers
# strikes
# raises
# stumbles
# crying
# lowers
# strikes
# raises
# stumbles
# crying
# lowers
# strikes
# raises
# stumbles
# crying
# lowers
# strikes
# raises
# stumbles
# crying
# lowers
# strikes
# ducks
# lowers
# strikes
# ducks
# lowers
# strikes
# ducks
# lowers
# strikes
# make
# lowers
# strikes
# make
# lowers
# strikes
# make
# heard
# searching
# goes
# searching
# goes
# looks
# jumps
# runs
# leaving
# strewn
# trash
# walks
# looks
# jumps
# runs
# leaving
# strewn
# trash
# walks
# looks
# jumps
# runs
# leaving
# strewn
# trash
# walks
# looks
# jumps
# runs
# leaving
# strewn
# trash
# walks
# looks
# jumps
# runs
# leaving
# strewn
# trash
# walks
# looks
# jumps
# runs
# leaving
# strewn
# trash
# walks
# looks
# jumps
# runs
# leaving
# strewn
# trash
# walks
# losing
# goes
# turns
# goes
# turns
# walks
# closes
# walks
# closes
# spreads
# close
# save
# looks
# closes
# spreads
# close
# save
# looks
# closes
# spreads
# close
# save
# looks
# closes
# spreads
# close
# save
# looks
# closes
# spreads
# close
# save
# looks
# closes
# join
# softens
# pray
# softens
# pray
# gasps
# approaching
# gasps
# approaching
# turns
# sniffs
# turns
# sniffs
# sniffs
# goes
# hide
# barks
# goes
# hide
# barks
# goes
# hide
# barks
# turns
# see
# throws
# turns
# see
# throws
# turns
# see
# throws
# takes
# carries
# takes
# carries
# disappears
# comes
# note
# holding
# chant
# holding
# chant
# notices
# rumbling
# notices
# rumbling
# looks
# rejoins
# chanting
# builds
# colored
# rises
# appears
# rejoins
# chanting
# builds
# colored
# rises
# appears
# rejoins
# chanting
# builds
# colored
# rises
# appears
# rejoins
# chanting
# builds
# colored
# rises
# appears
# rejoins
# chanting
# builds
# colored
# rises
# appears
# rejoins
# ...
# continues
# look
# notices
# goes
# arrive
# goes
# arrive
# blocks
# comes
# walks
# leaving
# confused
# walks
# leaving
# confused
# walks
# leaving
# confused
# packing
# heard
# walks
# making
# looks
# making
# looks
# revs
# making
# joins
# showing
# leaving
# returns
# revs
# making
# joins
# showing
# leaving
# returns
# revs
# making
# joins
# showing
# leaving
# returns
# revs
# making
# joins
# showing
# leaving
# returns
# revs
# making
# joins
# showing
# leaving
# returns
# revs
# making
# joins
# showing
# leaving
# returns
# heard
# comes
# sighs
# opens
# closes
# punching
# look
# walks
# turns
# look
# gasps
# proceeds
# show
# proceeds
# show
# opens
# lets
# opens
# lets
# changes
# arrives
# carrying
# arrives
# carrying
# kicks
# grabs
# run
# kicks
# grabs
# run
# kicks
# grabs
# run
# pointing
# opens
# turn
# shown
# written
# switches
# written
# switches
# starts
# playing
# seen
# starts
# playing
# seen
# starts
# playing
# seen
# points
# sits
# points
# sits
# holding
# throws
# switches
# shown
# throws
# switches
# shown
# throws
# switches
# shown
# arrives
# closes
# closes
# closes
# closes
# screams
# gets
# interrupted
# interrupted
# drops
# starts
# writing
# starts
# writing
# walks
# surveys
# walks
# surveys
# directs
# sees
# directs
# sees
# answer
# turns
# speaks
# turns
# speaks
# grabs
# leaves
# grabs
# leaves
# annoyed
# chuckling
# hangs
# burst
# laughing
# hangs
# burst
# laughing
# hangs
# burst
# laughing
# walks
# calm
# heard
# joins
# begins
# shout
# asking
# begins
# shout
# asking
# begins
# shout
# asking
# tries
# break
# tries
# break
# shown
# handcuffed
# carried
# shown
# handcuffed
# carried
# shown
# handcuffed
# carried
# shown
# hanged
# shown
# hanged
# shown
# shown
# sawed
# operate
# supervised
# shown
# sawed
# operate
# supervised
# shown
# sawed
# operate
# supervised
# shown
# sawed
# operate
# supervised
# shown
# holding
# enjoying
# shown
# gutted
# shown
# holding
# enjoying
# shown
# gutted
# shown
# holding
# enjoying
# shown
# gutted
# shown
# holding
# enjoying
# shown
# gutted
# shown
# holding
# enjoying
# shown
# gutted
# shown
# drinking
# collect
# shown
# drinking
# shown
# sitting
# shown
# drinking
# collect
# shown
# drinking
# shown
# sitting
# shown
# drinking
# collect
# shown
# drinking
# shown
# sitting
# shown
# drinking
# collect
# shown
# drinking
# shown
# sitting
# shown
# drinking
# collect
# shown
# drinking
# shown
# sitting
# shown
# drinking
# collect
# shown
# drinking
# shown
# sitting
# shown
# drinking
# collect
# shown
# drinking
# shown
# sitting
# opens
# accompanied
# opens
# accompanied
# stands
# starts
# beating
# pins
# strangling
# starts
# beating
# pins
# strangling
# starts
# beating
# pins
# strangling
# starts
# beating
# pins
# strangling
# choking
# choking
# stops
# strangling
# remains
# stops
# strangling
# remains
# stops
# strangling
# remains
# leaves
# remained
# leaves
# remained
# sighs
# walking
# looking
# turns
# look
# turns
# look
# looks
# stands
# points
# glaring
# walks
# picks
# walks
# picks
# looks
# looking
# taps
# annoyed
# turns
# looking
# annoyed
# listens
# turns
# looking
# annoyed
# listens
# turns
# looking
# annoyed
# listens
# turns
# looking
# annoyed
# listens
# rests
# saddens
# closing
# hangs
# lowers
# gets
# opens
# gets
# opens
# lunges
# screams
# lunges
# screams
# tied
# turning
# face
# turning
# face
# looks
# turns
# cuts
# drops
# tries
# hide
# drops
# tries
# hide
# drops
# tries
# hide
# panicked
# walking
# walking
# look
# looking
# walks
# walking
# turns
# walks
# turns
# walks
# walk
# unzips
# revealing
# unzips
# revealing
# pulls
# points
# runs
# punching
# runs
# punching
# walks
# leaving
# looking
# walks
# leaving
# looking
# walks
# leaving
# looking
# running
# grab
# walking
# looking
# showing
# run
# opens
# containing
# opens
# containing
# arms
# hands
# arms
# hands
# run
# reappearing
# run
# reappearing
# looking
# shouting
# begins
# cry
# begins
# cry
# starts
# ringing
# answers
# starts
# ringing
# answers
# starts
# ringing
# answers
# hangs
# looks
# glares
# looks
# offers
# takes
# walks
# takes
# walks
# turns
# taking
# resting
# turns
# taking
# resting
# turns
# taking
# resting
# lifts
# cuts
# unfolding
# cuts
# unfolding
# cutting
# waving
# looks
# lagging
# looks
# lagging
# covering
# turns
# turns
# face
# turns
# face
# appears
# messing
# appears
# messing
# realizes
# happening
# realizes
# happening
# continues
# alter
# continues
# alter
# transformed
# wearing
# transformed
# wearing
# turns
# runs
# pacing
# shrinks
# walks
# see
# happened
# transformed
# shrinks
# walks
# see
# happened
# transformed
# shrinks
# walks
# see
# happened
# transformed
# shrinks
# walks
# see
# happened
# transformed
# shrinks
# walks
# see
# happened
# transformed
# points
# circles
# circles
# turns
# reveal
# sitting
# turns
# reveal
# sitting
# turns
# reveal
# sitting
# flips
# revealing
# written
# flips
# revealing
# written
# flips
# revealing
# written
# flips
# opens
# check
# sitting
# opens
# check
# sitting
# opens
# check
# sitting
# looks
# cuts
# shuts
# flips
# gets
# reads
# rolls
# turns
# starts
# cheer
# starts
# cheer
# stops
# looks
# stops
# looks
# walking
# approaches
# appearing
# grunting
# drags
# turned
# grunting
# drags
# turned
# grunting
# drags
# turned
# look
# looks
# vaccinating
# laughs
# putting
# laughs
# putting
# leaving
# walk
# walking
# breaks
# coughing
# breaks
# coughing
# coughs
# continues
# coughing
# gasping
# continues
# coughing
# gasping
# continues
# coughing
# gasping
# begins
# sobbing
# smiling
# begins
# sobbing
# smiling
# begins
# sobbing
# smiling
# cheer
# partying
# selling
# groan
# dancing
# turns
# face
# turns
# face
# turns
# face
# turns
# face
# standing
# takes
# falls
# throws
# walks
# glaring
# walks
# glaring
# sighs
# cuts
# sits
# gets
# opens
# gets
# opens
# pulls
# leaves
# waves
# sits
# stare
# chimes
# waves
# sits
# stare
# chimes
# waves
# sits
# stare
# chimes
# waves
# sits
# stare
# chimes
# answer
# answers
# motions
# answer
# remain
# motions
# answer
# remain
# motions
# answer
# remain
# hangs
# walks
# answers
# enters
# leaving
# walks
# zooms
# walks
# zooms
# bursts
# runs
# hangs
# starts
# playing
# walks
# work
# enters
# wearing
# starts
# playing
# walks
# work
# enters
# wearing
# starts
# playing
# walks
# work
# enters
# wearing
# starts
# playing
# walks
# work
# enters
# wearing
# starts
# playing
# walks
# work
# enters
# wearing
# starts
# playing
# walks
# work
# enters
# wearing
# enters
# follows
# enters
# follows
# stands
# exits
# stands
# exits
# wearing
# glares
# flips
# look
# yawns
# look
# yawns
# raises
# look
# offended
# look
# offended
# pulls
# puts
# escorted
# rings
# enters
# rings
# enters
# starts
# singing
# starts
# singing
# pulls
# sits
# pulls
# sits
# pauses
# looking
# pauses
# looking
# arrest
# wearing
# attacks
# wearing
# attacks
# arrest
# turns
# running
# lifts
# turns
# running
# lifts
# turns
# running
# lifts
# turns
# enters
# starts
# crying
# looks
# starts
# crying
# looks
# starts
# crying
# looks
# murmur
# seen
# yawns
# plays
# cuts
# plays
# cuts
# gets
# leaving
# looking
# confused
# gets
# leaving
# looking
# confused
# gets
# leaving
# looking
# confused
# gets
# leaving
# looking
# confused
# looks
# pulls
# starts
# pulls
# starts
# snaps
# poses
# answers
# horrified
# calls
# watching
# answers
# watching
# answers
# notices
# plastered
# notices
# plastered
# speeds
# singing
# pulls
# puts
# pulls
# puts
# reaches
# returning
# ignoring
# leaves
# speaking
# cuts
# reading
# cuts
# reading
# cuts
# reading
# cuts
# reading
# leaning
# opening
# leaves
# closing
# leaves
# closing
# enters
# stops
# turns
# stops
# turns
# clicks
# looks
# chuckle
# annoyed
# storms
# raises
# claps
# walks
# claps
# walks
# drops
# walks
# drops
# walks
# walks
# grabs
# takes
# grabs
# takes
# runs
# see
# setting
# runs
# see
# setting
# runs
# see
# setting
# pulling
# walks
# rushing
# points
# grabs
# chases
# shouting
# chases
# shouting
# slams
# steps
# is
# cuts
# uplifting
# begins
# play
# uplifting
# begins
# play
# uplifting
# begins
# play
# struggling
# comes
# sits
# begins
# get
# begins
# get
# closes
# starts
# opening
# revealing
# starts
# opening
# revealing
# starts
# opening
# revealing
# continues
# set
# talks
# continues
# set
# talks
# continues
# set
# talks
# pulls
# sets
# pulls
# sets
# begins
# change
# begins
# change
# poses
# takes
# takes
# walks
# takes
# walks
# hands
# hands
# walks
# drags
# walks
# drags
# cuts
# gathered
# say
# cuts
# gathered
# say
# cuts
# gathered
# say
# walks
# motions
# come
# motions
# come
# starts
# walking
# following
# starts
# walking
# following
# starts
# walking
# following
# gets
# starts
# leave
# starts
# leave
# head
# hands
# leaves
# walks
# appears
# saying
# Looking
# Sell
# Call
# satisfy
# appears
# saying
# Looking
# Sell
# Call
# satisfy
# appears
# saying
# Looking
# Sell
# Call
# satisfy
# appears
# saying
# Looking
# Sell
# Call
# satisfy
# appears
# saying
# Looking
# Sell
# Call
# satisfy
# appears
# saying
# Looking
# Sell
# Call
# satisfy
# struggling
# ends
# arching
# heard
# cracking
# screams
# ends
# arching
# heard
# cracking
# screams
# ends
# arching
# heard
# cracking
# screams
# ends
# arching
# heard
# cracking
# screams
# ends
# arching
# heard
# cracking
# screams
# takes
# does
# ends
# snapping
# screaming
# snaps
# does
# ends
# snapping
# screaming
# snaps
# does
# ends
# snapping
# screaming
# snaps
# does
# ends
# snapping
# screaming
# snaps
# does
# ends
# snapping
# screaming
# snaps
# zooms
# begins
# cut
# mentioned
# starting
# begins
# cut
# mentioned
# starting
# begins
# cut
# mentioned
# starting
# begins
# cut
# mentioned
# starting
# cuts
# sitting
# cuts
# sitting
# hands
# calls
# hangs
# looks
# hangs
# looks
# stand
# begin
# posing
# stand
# begin
# posing
# stand
# begin
# posing
# pushes
# shows
# keep
# starts
# playing
# starts
# playing
# gets
# looks
# walks
# looks
# walks
# wounded
# looks
# looks
# walks
# looks
# walks
# opens
# sits
# feeling
# opens
# sits
# feeling
# opens
# sits
# feeling
# grabs
# sits
# grabs
# sits
# opens
# look
# points
# begin
# rush
# begin
# rush
# opens
# makes
# makes
# makes
# looks
# comes
# pulls
# crossed
# pulls
# crossed
# turns
# singing
# heard
# turns
# looking
# raising
# points
# clicks
# begins
# pooping
# begins
# pooping
# heard
# gets
# heard
# gets
# looks
# disinterested
# kneels
# whispers
# kneels
# whispers
# stops
# walking
# turns
# look
# stops
# walking
# turns
# look
# stops
# walking
# turns
# look
# stops
# walking
# turns
# look
# approaches
# pet
# approaches
# pet
# gets
# clicks
# attempts
# make
# go
# attempts
# make
# go
# attempts
# make
# go
# begins
# trot
# begins
# trot
# tries
# gain
# tries
# gain
# screams
# continues
# screams
# continues
# turns
# sees
# turns
# sees
# walks
# takes
# raise
# shows
# reads
# shows
# reads
# lowers
# says
# types
# says
# types
# start
# blaring
# shows
# start
# blaring
# shows
# start
# blaring
# shows
# knocks
# knocks
# misses
# looks
# reaches
# sits
# reaches
# sits
# starts
# moving
# starts
# moving
# chanting
# falls
# tries
# go
# help
# stops
# tries
# go
# help
# stops
# tries
# go
# help
# stops
# tries
# go
# help
# stops
# grabs
# puts
# grabs
# puts
# goes
# holding
# speaks
# goes
# holding
# speaks
# goes
# holding
# speaks
# clasps
# rushes
# gets
# walks
# check
# walks
# check
# pulls
# begin
# go
# begin
# go
# begins
# fire
# raises
# begins
# fire
# raises
# begins
# fire
# raises
# walks
# gets
# hands
# gets
# hands
# raises
# walks
# raises
# walks
# goes
# hits
# goes
# hits
# notices
# sniffles
# breaks
# crying
# breaks
# crying
# walks
# makes
# makes
# go
# open
# makes
# go
# open
# makes
# go
# open
# walks
# says
# enters
# slams
# shut
# enters
# slams
# shut
# enters
# slams
# shut
# slams
# shut
# slams
# shut
# raises
# takes
# hangs
# walks
# takes
# talk
# takes
# talk
# grabs
# walks
# answers
# playing
# screaming
# waiting
# tries
# opening
# locked
# knocks
# tries
# opening
# locked
# knocks
# tries
# opening
# locked
# knocks
# tries
# opening
# locked
# knocks
# knocks
# sits
# starts
# get
# eyed
# starts
# get
# eyed
# starts
# get
# eyed
# reaches
# crying
# reaches
# crying
# grabs
# cocks
# grabs
# cocks
# pulls
# fed
# turns
# infuriated
# walk
# starts
# playing
# walks
# equipped
# holding
# starts
# playing
# walks
# equipped
# holding
# starts
# playing
# walks
# equipped
# holding
# starts
# playing
# walks
# equipped
# holding
# starts
# playing
# walks
# equipped
# holding
# shoots
# walks
# cocks
# kicks
# cocks
# kicks
# sets
# starts
# shooting
# sets
# starts
# shooting
# sets
# starts
# shooting
# shooting
# takes
# provides
# runs
# sets
# opened
# runs
# cover
# provides
# runs
# sets
# opened
# runs
# cover
# provides
# runs
# sets
# opened
# runs
# cover
# provides
# runs
# sets
# opened
# runs
# cover
# provides
# runs
# sets
# opened
# runs
# cover
# provides
# runs
# sets
# opened
# runs
# cover
# sniffs
# prepares
# approach
# prepares
# approach
# throws
# explodes
# fall
# explodes
# fall
# plays
# points
# running
# plays
# points
# running
# plays
# points
# running
# makes
# comes
# dressed
# comes
# dressed
# shows
# leaves
# picks
# kicks
# puts
# tries
# tapdances
# sees
# dressed
# setting
# throws
# carrying
# sees
# dressed
# setting
# throws
# carrying
# sees
# dressed
# setting
# throws
# carrying
# sees
# dressed
# setting
# throws
# carrying
# sees
# dressed
# setting
# throws
# carrying
# heads
# singing
# gets
# reading
# gets
# reading
# comes
# walks
# wearing
# walks
# wearing
# notices
# walking
# wearing
# notices
# walking
# wearing
# notices
# walking
# wearing
# pinches
# groaning
# carry
# reading
# shows
# comes
# tries
# play
# hides
# comes
# tries
# play
# hides
# comes
# tries
# play
# hides
# comes
# tries
# play
# hides
# leaves
# punches
# begin
# fighting
# punches
# begin
# fighting
# punches
# begin
# fighting
# shows
# walks
# pinches
# slaps
# pinches
# slaps
# slaps
# gets
# leaves
# comes
# slaps
# gets
# leaves
# comes
# slaps
# gets
# leaves
# comes
# slaps
# gets
# leaves
# comes
# slaps
# starts
# praying
# starts
# praying
# opens
# shown
# carrying
# shown
# carrying
# pushes
# closes
# pushes
# closes
# leaves
# approaches
# leaves
# approaches
# leaves
# comes
# leaves
# comes
# answers
# watching
# rolls
# comes
# hangs
# narrating
# standing
# telling
# standing
# telling
# brings
# opens
# pushes
# closes
# opens
# pushes
# closes
# opens
# pushes
# closes
# pinches
# screams
# comes
# tases
# passes
# tases
# passes
# accompanies
# pinches
# takes
# winks
# opens
# wakes
# opens
# wakes
# leave
# takes
# leave
# takes
# makes
# lights
# takes
# lights
# takes
# takes
# takes
# walks
# keeping
# blows
# takes
# walks
# keeping
# blows
# takes
# walks
# keeping
# blows
# takes
# walks
# keeping
# blows
# brings
# join
# start
# smoking
# join
# start
# smoking
# join
# start
# smoking
# joins
# sits
# defeated
# sits
# defeated
# ignores
# rushes
# ignores
# rushes
# gets
# gets
# sparkles
# comes
# forces
# gets
# sparkles
# comes
# forces
# gets
# sparkles
# comes
# forces
# gets
# sparkles
# comes
# forces
# notice
# rainbows
# blasting
# rainbows
# blasting
# fires
# sending
# spinning
# fires
# sending
# spinning
# fires
# sending
# spinning
# tosses
# remaining
# knocking
# tosses
# remaining
# knocking
# tosses
# remaining
# knocking
# exit
# stays
# turns
# stays
# turns
# cuts
# escaping
# shown
# highlighted
# escaping
# shown
# highlighted
# escaping
# shown
# highlighted
# singing
# stops
# come
# stops
# come
# grabs
# crumbles
# throws
# grabs
# crumbles
# throws
# grabs
# crumbles
# throws
# go
# stop
# takes
# rips
# revealing
# rips
# revealing
# gasps
# gets
# flees
# draws
# notices
# pointing
# notices
# pointing
# cocks
# surrounded
# emerges
# looks
# descending
# taking
# looks
# descending
# taking
# looks
# descending
# taking
# pinches
# grabs
# humps
# grabs
# humps
# grabs
# fills
# approaches
# wearing
# Kiss
# written
# approaches
# wearing
# Kiss
# written
# approaches
# wearing
# Kiss
# written
# approaches
# wearing
# Kiss
# written
# licks
# wriggling
# licks
# wriggling
# runs
# approaches
# puts
# leave
# tosses
# disgusted
# tosses
# disgusted
# does
# narrating
# cuts
# walks
# plays
# comes
# walks
# takes
# leaves
# looking
# takes
# leaves
# looking
# takes
# leaves
# looking
# walks
# takes
# storms
# flies
# approaches
# whispers
# approaches
# whispers
# hands
# leaves
# listens
# walks
# angered
# walks
# angered
# flies
# holding
# hiding
# flies
# holding
# hiding
# flies
# holding
# hiding
# keeps
# talking
# watches
# keeps
# talking
# watches
# keeps
# talking
# watches
# pitched
# pitched
# pitched
# pitched
# pitched
# creeps
# smiles
# jumps
# takes
# prepares
# leave
# takes
# prepares
# leave
# takes
# prepares
# leave
# leave
# tries
# catch
# escapes
# laughing
# tries
# catch
# escapes
# laughing
# tries
# catch
# escapes
# laughing
# tries
# catch
# escapes
# laughing
# drives
# crashing
# taking
# left
# drives
# crashing
# taking
# left
# drives
# crashing
# taking
# left
# drives
# crashing
# taking
# left
# barges
# closing
# locking
# barges
# closing
# locking
# barges
# closing
# locking
# proceeds
# lock
# proceeds
# lock
# giving
# takes
# kicks
# walk
# see
# kicks
# walk
# see
# kicks
# walk
# see
# fires
# falls
# appear
# floating
# falls
# appear
# floating
# falls
# appear
# floating
# runs
# shatters
# scream
# fires
# shatters
# scream
# fires
# shatters
# scream
# fires
# starts
# running
# shot
# corner
# starts
# running
# shot
# corner
# starts
# running
# shot
# corner
# starts
# running
# shot
# corner
# tries
# walk
# follows
# run
# wall
# protect
# tries
# walk
# follows
# run
# wall
# protect
# tries
# walk
# follows
# run
# wall
# protect
# tries
# walk
# follows
# run
# wall
# protect
# tries
# walk
# follows
# run
# wall
# protect
# tries
# walk
# follows
# run
# wall
# protect
# flies
# hypnotized
# flies
# hypnotized
# turns
# stare
# holds
# shakes
# turns
# stare
# holds
# shakes
# turns
# stare
# holds
# shakes
# turns
# stare
# holds
# shakes
# starts
# walking
# starts
# walking
# hypnotized
# tries
# stop
# punches
# hypnotized
# tries
# stop
# punches
# hypnotized
# tries
# stop
# punches
# hypnotized
# tries
# stop
# punches
# grabs
# throws
# grabs
# throws
# tries
# escape
# tries
# escape
# struggles
# holds
# struggles
# holds
# shoves
# looks
# including
# stare
# confused
# looks
# including
# stare
# confused
# looks
# including
# stare
# confused
# looks
# including
# stare
# confused
# flies
# stand
# start
# clapping
# cheering
# stand
# start
# clapping
# cheering
# stand
# start
# clapping
# cheering
# stand
# start
# clapping
# cheering
# Chanting
# makes
# starts
# crying
# starts
# crying
# walk
# find
# walk
# find
# walks
# exchange
# continues
# talking
# exchange
# continues
# talking
# exchange
# continues
# talking
# rings
# begin
# leave
# begin
# leave
# sit
# opens
# see
# happening
# opens
# see
# happening
# opens
# see
# happening
# plays
# sees
# plays
# sees
# start
# leaving
# start
# leaving
# drops
# checks
# shown
# playing
# continuing
# shown
# playing
# continuing
# shown
# playing
# continuing
# hits
# smashing
# hits
# smashing
# come
# typing
# stops
# goes
# unamused
# walks
# approaches
# walks
# approaches
# punches
# screaming
# motions
# echoing
# starts
# leaving
# looks
# see
# moving
# starts
# leaving
# looks
# see
# moving
# starts
# leaving
# looks
# see
# moving
# starts
# leaving
# looks
# see
# moving
# starts
# leaving
# looks
# see
# moving
# sobbing
# continues
# cry
# continues
# cry
# smiles
# walks
# respond
# leaves
# points
# hands
# flushes
# makes
# flushes
# makes
# makes
# signs
# presses
# presses
# walks
# pours
# makes
# presses
# barges
# walks
# knocking
# opens
# kicks
# grabs
# trying
# stop
# grabs
# trying
# stop
# grabs
# trying
# stop
# runs
# laughs
# joining
# laughs
# joining
# walks
# stops
# walking
# stops
# walking
# screams
# walks
# chuckles
# chuckling
# pushes
# catches
# leaves
# walks
# interrupting
# walks
# interrupting
# muffled
# muffled
# muffled
# turns
# face
# turns
# face
# muffled
# kisses
# throws
# makes
# nudges
# walks
# nudges
# walks
# offended
# infuriated
# infuriated
# sobbing
# repeated

# %%
fin_verbs
# Out:
# [runs,
#  chortles,
#  faces,
#  laugh,
#  knocking,
#  laughs,
#  drives,
#  gets,
#  drives,
#  gets,
#  Waddles,
#  Turning,
#  see,
#  Turning,
#  see,
#  runs,
#  laugh,
#  drowned,
#  rising,
#  walks,
#  shouts,
#  fire,
#  Drives,
#  flashing,
#  Drives,
#  flashing,
#  pursues,
#  fire,
#  hands,
#  leaves,
#  follow,
#  glances,
#  gets,
#  shouts,
#  hear,
#  shouts,
#  hear,
#  Turning,
#  face,
#  Turning,
#  face,
#  Pulling,
#  gets,
#  gets,
#  walks,
#  hurries,
#  walks,
#  stops,
#  Turns,
#  moves,
#  walks,
#  following,
#  walks,
#  following,
#  walks,
#  fire,
#  looks,
#  Driving,
#  stops,
#  Driving,
#  stops,
#  appear,
#  shrugs,
#  leave,
#  Thinking,
#  Passing,
#  Stopping,
#  singing,
#  Turning,
#  face,
#  Turning,
#  face,
#  Shrieking,
#  Hushed,
#  Rushing,
#  Takes,
#  run,
#  Flashes,
#  Crowd,
#  Snapping,
#  Muffled,
#  Whining,
#  Arresting,
#  Drops,
#  Beeps,
#  Thump,
#  turns,
#  Rowing,
#  Shoots,
#  Sees,
#  dressed,
#  Sees,
#  dressed,
#  Hushed,
#  drops,
#  leave,
#  Looking,
#  distracted,
#  sees,
#  laugh,
#  starts,
#  punches,
#  punches,
#  leaves,
#  enter,
#  heckling,
#  rushes,
#  shaking,
#  mocking,
#  Whining,
#  laughs,
#  Wagging,
#  Pissed,
#  Swooning,
#  Heading,
#  labored,
#  stopping,
#  hushed,
#  pointing,
#  concerned,
#  darting,
#  leans,
#  Getting,
#  Taunting,
#  torches,
#  begin,
#  conceal,
#  begin,
#  conceal,
#  Holding,
#  Sees,
#  coming,
#  Sees,
#  coming,
#  moves,
#  Falls,
#  Drops,
#  leaves,
#  leaves,
#  Thumps,
#  Tosses,
#  pinned,
#  Slapping,
#  Gets,
#  moves,
#  Gets,
#  moves,
#  Swings,
#  pick,
#  ends,
#  looks,
#  Turning,
#  Thinks,
#  Puts,
#  laughing,
#  Rushing,
#  Panicking,
#  throws,
#  sobbing,
#  throws,
#  sheds,
#  turns,
#  walks,
#  sheds,
#  turns,
#  walks,
#  sheds,
#  turns,
#  walks,
#  starts,
#  starts,
#  sway,
#  starts,
#  starts,
#  sway,
#  starts,
#  starts,
#  sway,
#  grins,
#  Enunciating,
#  Looks,
#  Feigning,
#  clearing,
#  Feigning,
#  clearing,
#  opens,
#  opens,
#  Waving,
#  screaming,
#  continues,
#  Shows,
#  gains,
#  Strolling,
#  Examines,
#  Revealing,
#  Braking,
#  starts,
#  convulsing,
#  starts,
#  convulsing,
#  crushes,
#  steps,
#  watching,
#  steps,
#  watching,
#  throws,
#  rips,
#  grabs,
#  drops,
#  throws,
#  rips,
#  grabs,
#  drops,
#  throws,
#  rips,
#  grabs,
#  drops,
#  throws,
#  rips,
#  grabs,
#  drops,
#  looks,
#  mortified,
#  opens,
#  looks,
#  mortified,
#  opens,
#  looks,
#  mortified,
#  opens,
#  takes,
#  Looks,
#  looks,
#  ends,
#  stands,
#  Takes,
#  resumes,
#  playing,
#  resumes,
#  playing,
#  Weighs,
#  begins,
#  play,
#  begins,
#  play,
#  plays,
#  Interrupting,
#  looks,
#  follows,
#  looks,
#  follows,
#  come,
#  start,
#  kissing,
#  come,
#  start,
#  kissing,
#  come,
#  start,
#  kissing,
#  cupped,
#  playing,
#  Studying,
#  Drags,
#  Does,
#  Dejected,
#  pulls,
#  throws,
#  Moves,
#  Grabs,
#  Looks,
#  look,
#  dances,
#  Approaching,
#  stops,
#  Turns,
#  turns,
#  picks,
#  walks,
#  picks,
#  walks,
#  drops,
#  Jumps,
#  turns,
#  see,
#  Jumps,
#  turns,
#  see,
#  Jumps,
#  turns,
#  see,
#  Trying,
#  Blinks,
#  Eyebrows,
#  Looks,
#  Looks,
#  Looks,
#  Pissed,
#  scratches,
#  Enunciating,
#  heard,
#  plays,
#  laugh,
#  Approaching,
#  Bangs,
#  Thumps,
#  Coming,
#  Wondering,
#  leave,
#  laugh,
#  leaves,
#  dressed,
#  Reads,
#  Takes,
#  Takes,
#  turns,
#  leave,
#  turns,
#  leave,
#  join,
#  looks,
#  Returning,
#  Thumps,
#  Thumps,
#  Hangs,
#  gasp,
#  go,
#  runs,
#  blows,
#  blows,
#  go,
#  runs,
#  blows,
#  blows,
#  go,
#  runs,
#  blows,
#  blows,
#  go,
#  runs,
#  blows,
#  blows,
#  Embraces,
#  Pulls,
#  Walking,
#  Goes,
#  Listening,
#  Getting,
#  Grabbing,
#  lift,
#  Aroused,
#  Close,
#  Rises,
#  follows,
#  pass,
#  Pained,
#  Grabs,
#  Drops,
#  departs,
#  drawn,
#  Looking,
#  Falls,
#  speaks,
#  appears,
#  seen,
#  flinch,
#  throws,
#  flinch,
#  throws,
#  Catches,
#  Opening,
#  Opens,
#  Snuggling,
#  Rubs,
#  raises,
#  withdraws,
#  covers,
#  shown,
#  squatting,
#  shown,
#  squatting,
#  keep,
#  eating,
#  keep,
#  eating,
#  Drops,
#  widen,
#  Pulls,
#  Coming,
#  pulls,
#  Boiling,
#  looks,
#  looks,
#  come,
#  floats,
#  Takes,
#  Coming,
#  Pulls,
#  Puts,
#  Drives,
#  Slaps,
#  Wipes,
#  Turns,
#  Wringing,
#  Throttling,
#  leave,
#  Walks,
#  Points,
#  Takes,
#  Steps,
#  carried,
#  looks,
#  moves,
#  Taking,
#  Doing,
#  checks,
#  Winking,
#  Displays,
#  Stepping,
#  Pulls,
#  Reading,
#  Recalls,
#  Sips,
#  Takes,
#  Gets,
#  Rushing,
#  puts,
#  Going,
#  Turns,
#  Lowers,
#  Enunciating,
#  Leaning,
#  Imitating,
#  Following,
#  Thumps,
#  Sobbing,
#  Starts,
#  move,
#  Starts,
#  move,
#  Peels,
#  Rushing,
#  Smoking,
#  get,
#  gasps,
#  Holds,
#  drops,
#  leaves,
#  Doing,
#  starts,
#  sob,
#  starts,
#  sob,
#  leave,
#  Getting,
#  Grousing,
#  Gives,
#  Pointing,
#  reach,
#  Subdued,
#  tosses,
#  Gives,
#  flips,
#  sporting,
#  looks,
#  draws,
#  looks,
#  embrace,
#  Gets,
#  get,
#  moves,
#  Follows,
#  looking,
#  Blows,
#  Giggling,
#  falls,
#  Arriving,
#  Rising,
#  Sits,
#  Grumbling,
#  begins,
#  Reaches,
#  Interrupting,
#  Vindicated,
#  Laying,
#  Walking,
#  Reads,
#  Wiping,
#  flies,
#  Firing,
#  Reading,
#  talk,
#  Pounds,
#  whispers,
#  bandaged,
#  Popping,
#  Thinks,
#  Holding,
#  Resumes,
#  filming,
#  Resumes,
#  filming,
#  Pops,
#  Moves,
#  Looks,
#  Relishing,
#  Sobbing,
#  Pinned,
#  Retreating,
#  Comes,
#  stands,
#  Comes,
#  stands,
#  Finishes,
#  Turns,
#  baiting,
#  Resumes,
#  eating,
#  Resumes,
#  eating,
#  Turns,
#  starts,
#  Shouting,
#  begins,
#  hyperventilate,
#  begins,
#  hyperventilate,
#  sits,
#  turns,
#  face,
#  turns,
#  face,
#  Faces,
#  Facing,
#  Holds,
#  Rushing,
#  Sees,
#  Thinks,
#  Running,
#  Drops,
#  Pointing,
#  hurrying,
#  get,
#  look,
#  get,
#  look,
#  reaches,
#  Switch,
#  Switch,
#  Hangs,
#  Emerging,
#  Pushes,
#  Drives,
#  Writes,
#  Grins,
#  Looking,
#  answers,
#  hangs,
#  resumes,
#  hangs,
#  resumes,
#  notice,
#  Walking,
#  Rushing,
#  Passing,
#  Taunting,
#  walk,
#  Moaning,
#  Rushing,
#  Rising,
#  Gasping,
#  Turns,
#  Determined,
#  talking,
#  hanging,
#  talking,
#  hanging,
#  Sitting,
#  Mocking,
#  Picks,
#  Looking,
#  crossed,
#  pulls,
#  Happening,
#  Stopping,
#  Singing,
#  Weeping,
#  Concerned,
#  Arriving,
#  Facing,
#  Turns,
#  face,
#  Turns,
#  face,
#  Rushes,
#  returns,
#  Put,
#  pulls,
#  tosses,
#  Flying,
#  Crying,
#  Recovering,
#  Fleeing,
#  Gazing,
#  Stopping,
#  scratches,
#  Intruding,
#  Setting,
#  Walks,
#  Scanning,
#  finished,
#  setting,
#  finished,
#  setting,
#  creeps,
#  Hushed,
#  Turning,
#  Recoiling,
#  Whining,
#  Whining,
#  Threatening,
#  spits,
#  Turns,
#  Closing,
#  Releases,
#  trails,
#  leave,
#  Turns,
#  Subdued,
#  Walks,
#  Rushing,
#  Pointing,
#  Rising,
#  Rising,
#  Gets,
#  leaves,
#  throws,
#  Puffs,
#  Hiding,
#  Coming,
#  shut,
#  stare,
#  Rubbing,
#  Whining,
#  amused,
#  appears,
#  connecting,
#  appears,
#  connecting,
#  Clears,
#  affects,
#  Clears,
#  affects,
#  Slapping,
#  Tallying,
#  popping,
#  counting,
#  taunting,
#  Noticing,
#  Responding,
#  Turning,
#  appears,
#  opens,
#  pour,
#  opens,
#  pour,
#  rain,
#  swim,
#  rain,
#  swim,
#  Doing,
#  Snapping,
#  skipping,
#  Coming,
#  Rushing,
#  Snapping,
#  Looking,
#  Intrigued,
#  Walks,
#  Thinks,
#  trying,
#  Stopping,
#  Sliding,
#  Enunciating,
#  Rubs,
#  walks,
#  Wiggling,
#  Entering,
#  Staring,
#  leaves,
#  Staring,
#  leaves,
#  Seated,
#  Pulls,
#  shaking,
#  Muffled,
#  Running,
#  step,
#  Thinks,
#  Pulls,
#  Ignoring,
#  speaking,
#  Ignoring,
#  speaking,
#  stops,
#  Grabbing,
#  Whispers,
#  wavering,
#  Passes,
#  Putting,
#  Senses,
#  Hangs,
#  Rushing,
#  walk,
#  Pulls,
#  Examining,
#  Dejected,
#  starts,
#  sobbing,
#  starts,
#  sobbing,
#  Vocalizing,
#  Walks,
#  Dropping,
#  turns,
#  closes,
#  turns,
#  closes,
#  lifts,
#  looks,
#  sits,
#  swims,
#  lifts,
#  looks,
#  sits,
#  swims,
#  lifts,
#  looks,
#  sits,
#  swims,
#  lifts,
#  looks,
#  sits,
#  swims,
#  gets,
#  picks,
#  throws,
#  goes,
#  looks,
#  gets,
#  picks,
#  throws,
#  goes,
#  looks,
#  gets,
#  picks,
#  throws,
#  goes,
#  looks,
#  gets,
#  picks,
#  throws,
#  goes,
#  looks,
#  gets,
#  picks,
#  throws,
#  goes,
#  looks,
#  pulls,
#  knock,
#  opens,
#  looks,
#  see,
#  opens,
#  looks,
#  see,
#  opens,
#  looks,
#  see,
#  dressed,
#  look,
#  walks,
#  hops,
#  approaches,
#  hops,
#  approaches,
#  blinks,
#  looks,
#  follow,
#  sees,
#  blinks,
#  looks,
#  follow,
#  sees,
#  blinks,
#  looks,
#  follow,
#  sees,
#  blinks,
#  looks,
#  follow,
#  sees,
#  runs,
#  pulls,
#  drops,
#  looks,
#  runs,
#  pulls,
#  drops,
#  looks,
#  runs,
#  pulls,
#  drops,
#  looks,
#  runs,
#  pulls,
#  drops,
#  looks,
#  shuts,
#  opens,
#  shuts,
#  opens,
#  shuts,
#  opens,
#  shuts,
#  opens,
#  shuts,
#  opens,
#  shuts,
#  opens,
#  jumps,
#  runs,
#  rushes,
#  jumps,
#  runs,
#  rushes,
#  jumps,
#  runs,
#  rushes,
#  comes,
#  walks,
#  buries,
#  begins,
#  sob,
#  buries,
#  begins,
#  sob,
#  buries,
#  begins,
#  sob,
#  looks,
#  runs,
#  enters,
#  turns,
#  enters,
#  turns,
#  pointing,
#  left,
#  stands,
#  approaches,
#  slaps,
#  leaves,
#  stands,
#  approaches,
#  slaps,
#  leaves,
#  stands,
#  approaches,
#  slaps,
#  leaves,
#  stands,
#  approaches,
#  slaps,
#  leaves,
#  turns,
#  closes,
#  turns,
#  closes,
#  gasps,
#  lies,
#  gasps,
#  lies,
#  freezes,
#  sees,
#  quivering,
#  freezes,
#  sees,
#  quivering,
#  freezes,
#  sees,
#  quivering,
#  rushes,
#  comfort,
#  rushes,
#  comfort,
#  covers,
#  kisses,
#  gets,
#  kisses,
#  gets,
#  starts,
#  drag,
#  starts,
#  drag,
#  drags,
#  looks,
#  drags,
#  looks,
#  turns,
#  writes,
#  blows,
#  writes,
#  blows,
#  appears,
#  sees,
#  pass,
#  sees,
#  pass,
#  enters,
#  holds,
#  holds,
#  looks,
#  drags,
#  looks,
#  drags,
#  brings,
#  sets,
#  brings,
#  sets,
#  says,
#  enters,
#  says,
#  enters,
#  squeezes,
#  walks,
#  squeezes,
#  walks,
#  cuts,
#  clear,
#  cuts,
#  clear,
#  works,
#  goes,
#  comes,
#  gives,
#  look,
#  seeing,
#  walks,
#  rings,
#  answering,
#  show,
#  missing,
#  show,
#  missing,
#  moves,
#  head,
#  await,
#  pulling,
#  pulls,
#  walks,
#  moves,
#  head,
#  await,
#  pulling,
#  pulls,
#  walks,
#  moves,
#  head,
#  await,
#  pulling,
#  pulls,
#  walks,
#  moves,
#  head,
#  await,
#  pulling,
#  pulls,
#  walks,
#  moves,
#  head,
#  await,
#  pulling,
#  pulls,
#  walks,
#  moves,
#  head,
#  await,
#  pulling,
#  pulls,
#  walks,
#  falls,
#  hit,
#  falls,
#  hit,
#  missing,
#  tied,
#  missing,
#  tied,
#  dressed,
#  ...]

# %%
from collections import Counter

Counter(fin_verbs)
# Out:
# Counter({plays: 27,
#          following: 27,
#          flows: 27,
#          closes: 27,
#          handwritten: 27,
#          looks: 27,
#          playing: 27,
#          like: 27,
#          listen: 27,
#          looks: 27,
#          returns: 27,
#          stops: 27,
#          putting: 27,
#          listen: 27,
#          wearing: 27,
#          dancing: 27,
#          looks: 27,
#          waves: 27,
#          conducting: 27,
#          listening: 27,
#          wearing: 27,
#          dancing: 27,
#          looking: 27,
#          moves: 27,
#          delete: 27,
#          gone: 27,
#          shuts: 27,
#          arrives: 24,
#          grabs: 24,
#          butters: 24,
#          leaves: 24,
#          rubs: 24,
#          struggles: 24,
#          pops: 24,
#          falling: 24,
#          stumbles: 24,
#          rises: 24,
#          stumbles: 24,
#          stands: 24,
#          raises: 24,
#          raises: 24,
#          exposed: 24,
#          notices: 24,
#          lowers: 24,
#          raises: 24,
#          rises: 24,
#          lowers: 24,
#          walks: 24,
#          transmits: 24,
#          dabs: 24,
#          leaving: 24,
#          reaches: 24,
#          pulls: 24,
#          called: 24,
#          leaves: 24,
#          draw: 24,
#          smashes: 24,
#          destroyed: 24,
#          gets: 24,
#          peels: 24,
#          rushes: 24,
#          runs: 24,
#          turns: 24,
#          begins: 24,
#          delete: 24,
#          has: 24,
#          opens: 24,
#          pulls: 24,
#          takes: 24,
#          puts: 24,
#          sets: 24,
#          operated: 24,
#          launches: 24,
#          rushes: 24,
#          glances: 24,
#          looking: 24,
#          created: 24,
#          begins: 24,
#          show: 24,
#          closes: 24,
#          shown: 24,
#          shows: 24,
#          putting: 24,
#          notices: 24,
#          looking: 24,
#          looking: 24,
#          puts: 24,
#          shows: 24,
#          leaves: 24,
#          grabs: 24,
#          delay: 24,
#          receiving: 24,
#          reads: 24,
#          has: 24,
#          holding: 24,
#          turning: 24,
#          crying: 24,
#          shows: 24,
#          having: 24,
#          walks: 23,
#          lays: 23,
#          responds: 23,
#          responds: 23,
#          slams: 23,
#          shatters: 23,
#          stands: 23,
#          shattering: 23,
#          kicks: 23,
#          delivers: 23,
#          snaps: 23,
#          remaining: 23,
#          breaks: 23,
#          punches: 23,
#          punches: 23,
#          snaps: 23,
#          jabs: 23,
#          takes: 23,
#          takes: 23,
#          jabs: 23,
#          walks: 23,
#          throws: 23,
#          aims: 23,
#          pulls: 21,
#          goes: 21,
#          shows: 21,
#          's: 21,
#          unzips: 21,
#          puts: 21,
#          gets: 21,
#          ties: 21,
#          moves: 21,
#          had: 21,
#          takes: 21,
#          goes: 21,
#          holds: 21,
#          flies: 21,
#          turns: 21,
#          drops: 21,
#          dances: 21,
#          turns: 21,
#          left: 21,
#          appears: 21,
#          popping: 21,
#          embrace: 20,
#          takes: 20,
#          stands: 20,
#          walks: 20,
#          takes: 20,
#          stands: 20,
#          takes: 20,
#          tosses: 20,
#          approaches: 20,
#          removes: 20,
#          takes: 20,
#          looks: 20,
#          goes: 20,
#          remove: 20,
#          tosses: 20,
#          bends: 20,
#          remove: 20,
#          tosses: 20,
#          coaxes: 20,
#          follows: 20,
#          enters: 19,
#          begins: 19,
#          falls: 19,
#          turns: 19,
#          plays: 19,
#          picks: 19,
#          groans: 19,
#          cover: 19,
#          lifts: 19,
#          wailing: 19,
#          joins: 19,
#          plays: 19,
#          swallows: 19,
#          appears: 19,
#          pushes: 19,
#          groans: 19,
#          finishes: 19,
#          cheer: 19,
#          pissed: 19,
#          plays: 18,
#          gets: 18,
#          gets: 18,
#          walks: 18,
#          reaches: 18,
#          pulls: 18,
#          plants: 18,
#          opens: 18,
#          pours: 18,
#          drinks: 18,
#          transforms: 18,
#          flips: 18,
#          turns: 18,
#          breaks: 18,
#          obliterating: 18,
#          runs: 18,
#          find: 18,
#          looks: 18,
#          gives: 18,
#          holds: 18,
#          takes: 18,
#          puts: 18,
#          pour: 18,
#          comes: 18,
#          reveal: 18,
#          takes: 18,
#          shoots: 18,
#          stunned: 18,
#          walks: 18,
#          comes: 18,
#          takes: 18,
#          puts: 18,
#          smiles: 18,
#          remain: 18,
#          clap: 18,
#          left: 18,
#          turns: 17,
#          walks: 17,
#          looks: 17,
#          follows: 17,
#          turns: 17,
#          walks: 17,
#          walking: 17,
#          stops: 17,
#          appears: 17,
#          sees: 17,
#          starts: 17,
#          turns: 17,
#          begins: 17,
#          run: 17,
#          looms: 17,
#          lets: 17,
#          go: 17,
#          walk: 17,
#          dump: 17,
#          walk: 17,
#          looks: 17,
#          starts: 17,
#          getting: 17,
#          stands: 17,
#          grins: 17,
#          walks: 17,
#          walks: 17,
#          bangs: 17,
#          lets: 17,
#          go: 17,
#          moves: 17,
#          bangs: 17,
#          moves: 17,
#          bangs: 17,
#          appear: 16,
#          going: 16,
#          screaming: 16,
#          head: 16,
#          crash: 16,
#          fall: 16,
#          pop: 16,
#          begins: 16,
#          pour: 16,
#          broke: 16,
#          crashing: 16,
#          follows: 16,
#          rushes: 16,
#          flooded: 16,
#          riding: 16,
#          rises: 16,
#          opens: 16,
#          pulls: 16,
#          begins: 16,
#          cut: 16,
#          gets: 16,
#          rubs: 16,
#          gets: 16,
#          shape: 16,
#          cuts: 16,
#          rips: 16,
#          gets: 16,
#          puts: 16,
#          gets: 16,
#          rubs: 16,
#          shocked: 16,
#          sees: 16,
#          closes: 16,
#          locks: 16,
#          arms: 16,
#          goes: 16,
#          wait: 16,
#          call: 16,
#          pounds: 16,
#          gives: 16,
#          goes: 16,
#          goes: 16,
#          gets: 16,
#          pissed: 16,
#          breaks: 16,
#          's: 16,
#          comes: 16,
#          answers: 16,
#          ManBearPig: 16,
#          roars: 16,
#          roars: 16,
#          faces: 16,
#          run: 16,
#          leaps: 16,
#          sending: 16,
#          sets: 16,
#          gets: 16,
#          turns: 16,
#          run: 16,
#          throws: 16,
#          bounces: 16,
#          grapple: 16,
#          grabs: 16,
#          rips: 16,
#          picks: 16,
#          starts: 16,
#          using: 16,
#          looks: 16,
#          puts: 16,
#          stop: 16,
#          crying: 16,
#          begin: 16,
#          crawl: 16,
#          walk: 16,
#          pass: 16,
#          stops: 16,
#          open: 16,
#          show: 16,
#          looks: 16,
#          move: 16,
#          takes: 15,
#          holds: 15,
#          goes: 15,
#          pulls: 15,
#          wear: 15,
#          wearing: 15,
#          gets: 15,
#          inspect: 15,
#          including: 15,
#          line: 15,
#          inspects: 15,
#          pokes: 15,
#          gives: 15,
#          begins: 15,
#          turning: 15,
#          approaches: 15,
#          reaches: 15,
#          falls: 15,
#          hoists: 15,
#          carries: 15,
#          carries: 15,
#          gathered: 15,
#          marvel: 15,
#          admiring: 15,
#          wipes: 15,
#          carries: 15,
#          closes: 15,
#          goes: 15,
#          keep: 15,
#          applauding: 15,
#          throw: 15,
#          try: 15,
#          wrestle: 15,
#          budge: 15,
#          start: 15,
#          crawl: 15,
#          break: 15,
#          start: 15,
#          falling: 15,
#          barge: 15,
#          looks: 15,
#          drops: 15,
#          join: 15,
#          grab: 15,
#          scream: 15,
#          plays: 15,
#          follows: 15,
#          play: 15,
#          continue: 15,
#          working: 15,
#          typing: 15,
#          having: 15,
#          writing: 15,
#          brought: 15,
#          enters: 15,
#          put: 15,
#          puts: 15,
#          notices: 15,
#          working: 15,
#          reaches: 15,
#          hops: 15,
#          puts: 15,
#          going: 15,
#          walks: 15,
#          join: 15,
#          returns: 15,
#          open: 15,
#          pull: 15,
#          opens: 15,
#          takes: 15,
#          closes: 15,
#          puts: 15,
#          bother: 15,
#          put: 15,
#          closes: 15,
#          removes: 15,
#          gives: 15,
#          straightens: 15,
#          gets: 15,
#          removed: 15,
#          given: 15,
#          lengthened: 15,
#          given: 15,
#          given: 15,
#          made: 15,
#          look: 15,
#          fixed: 15,
#          given: 15,
#          sweating: 15,
#          raps: 15,
#          heard: 14,
#          aimed: 14,
#          targeted: 14,
#          turns: 14,
#          looks: 14,
#          looks: 14,
#          turns: 14,
#          shown: 14,
#          turns: 14,
#          left: 14,
#          start: 14,
#          walking: 14,
#          remain: 14,
#          trained: 14,
#          lifts: 14,
#          look: 14,
#          move: 14,
#          groans: 14,
#          sees: 14,
#          moves: 14,
#          passes: 14,
#          remains: 14,
#          reaches: 14,
#          breaks: 14,
#          cheer: 14,
#          approach: 14,
#          begins: 14,
#          play: 14,
#          hits: 14,
#          goes: 14,
#          twisting: 14,
#          ending: 14,
#          arrives: 14,
#          honks: 14,
#          strikes: 14,
#          pushes: 14,
#          strikes: 14,
#          blows: 14,
#          burning: 14,
#          get: 14,
#          run: 14,
#          flies: 14,
#          gather: 14,
#          hoist: 14,
#          carrying: 14,
#          lowered: 14,
#          fills: 14,
#          holds: 14,
#          thinks: 14,
#          makes: 14,
#          votes: 14,
#          considers: 14,
#          approaches: 14,
#          drops: 14,
#          holding: 14,
#          spins: 14,
#          turns: 14,
#          heads: 14,
#          enters: 14,
#          grabs: 14,
#          turns: 14,
#          pours: 14,
#          turns: 14,
#          pour: 14,
#          closes: 14,
#          opens: 14,
#          gets: 14,
#          pours: 14,
#          closes: 14,
#          presses: 14,
#          shoots: 14,
#          goes: 14,
#          gargles: 14,
#          shoots: 14,
#          lives: 14,
#          takes: 14,
#          cocks: 14,
#          shown: 14,
#          heard: 14,
#          kill: 14,
#          shoots: 14,
#          kills: 14,
#          writhes: 14,
#          dies: 14,
#          crawls: 14,
#          gets: 14,
#          trips: 14,
#          descends: 14,
#          dodges: 14,
#          runs: 14,
#          runs: 14,
#          trips: 14,
#          sliding: 14,
#          drops: 14,
#          traps: 14,
#          looks: 14,
#          sees: 14,
#          crowd: 14,
#          left: 14,
#          looks: 14,
#          begins: 14,
#          move: 14,
#          reaches: 14,
#          opens: 14,
#          looking: 14,
#          eat: 14,
#          looks: 14,
#          finds: 14,
#          climbs: 14,
#          starts: 14,
#          eating: 14,
#          getting: 14,
#          howls: 13,
#          stomps: 13,
#          hops: 13,
#          walks: 13,
#          bats: 13,
#          takes: 13,
#          stops: 13,
#          landing: 13,
#          starts: 13,
#          kissing: 13,
#          removes: 13,
#          looks: 13,
#          looks: 13,
#          reaches: 13,
#          turns: 13,
#          tries: 13,
#          sleep: 13,
#          goes: 13,
#          takes: 13,
#          swallows: 13,
#          turns: 13,
#          looks: 13,
#          annoyed: 13,
#          turns: 13,
#          tries: 13,
#          sleep: 13,
#          fires: 13,
#          go: 13,
#          pours: 13,
#          reaches: 13,
#          get: 13,
#          sets: 13,
#          gets: 13,
#          throws: 13,
#          follows: 13,
#          hits: 13,
#          drops: 13,
#          realizes: 13,
#          means: 13,
#          loses: 13,
#          causes: 13,
#          hit: 13,
#          erupts: 13,
#          begins: 13,
#          spread: 13,
#          torching: 13,
#          burning: 13,
#          breaks: 13,
#          runs: 13,
#          hop: 13,
#          break: 13,
#          pulls: 13,
#          approach: 13,
#          see: 13,
#          happening: 13,
#          looks: 13,
#          leave: 13,
#          moves: 13,
#          resting: 13,
#          falls: 13,
#          comes: 13,
#          climax: 13,
#          shown: 13,
#          covers: 13,
#          ends: 13,
#          begins: 13,
#          fidget: 13,
#          got: 13,
#          get: 13,
#          hits: 13,
#          runs: 13,
#          gets: 13,
#          shoves: 13,
#          lowers: 13,
#          leaves: 13,
#          looks: 13,
#          stunned: 13,
#          looks: 13,
#          observe: 13,
#          burning: 13,
#          sneaks: 13,
#          distracted: 13,
#          dashes: 13,
#          enters: 13,
#          hops: 13,
#          attaches: 13,
#          begins: 13,
#          typing: 13,
#          pop: 13,
#          opens: 13,
#          enter: 13,
#          understands: 13,
#          runs: 13,
#          goes: 13,
#          tosses: 13,
#          needed: 13,
#          finds: 13,
#          pulls: 13,
#          blows: 13,
#          reads: 13,
#          Open: 13,
#          instructed: 13,
#          messes: 13,
#          pops: 13,
#          runs: 13,
#          knocks: 13,
#          found: 13,
#          opens: 13,
#          falls: 13,
#          looks: 13,
#          gasps: 13,
#          sees: 13,
#          covered: 13,
#          written: 13,
#          reaches: 13,
#          looks: 13,
#          squints: 13,
#          asked: 13,
#          join: 13,
#          went: 13,
#          question: 13,
#          agreed: 13,
#          go: 13,
#          has: 13,
#          looks: 13,
#          focuses: 13,
#          stop: 13,
#          get: 13,
#          knocks: 13,
#          answers: 13,
#          pushes: 13,
#          squats: 13,
#          get: 13,
#          remove: 13,
#          hops: 13,
#          hops: 13,
#          gets: 13,
#          lubricate: 13,
#          pretends: 13,
#          stroke: 13,
#          pops: 13,
#          tosses: 13,
#          catches: 13,
#          looking: 13,
#          start: 13,
#          fighting: 13,
#          including: 13,
#          gather: 13,
#          watch: 13,
#          including: 13,
#          cheering: 13,
#          including: 13,
#          stay: 13,
#          stops: 13,
#          see: 13,
#          going: 13,
#          punches: 13,
#          flying: 13,
#          walks: 13,
#          punches: 13,
#          turns: 13,
#          walks: 13,
#          close: 13,
#          returns: 13,
#          throws: 13,
#          hits: 13,
#          falls: 13,
#          walks: 13,
#          laughs: 13,
#          follows: 13,
#          stops: 13,
#          turns: 13,
#          rolls: 13,
#          smokes: 13,
#          tosses: 13,
#          explode: 13,
#          making: 13,
#          run: 13,
#          blow: 13,
#          leave: 13,
#          turn: 13,
#          watch: 13,
#          sees: 13,
#          turns: 13,
#          running: 13,
#          gets: 13,
#          scoops: 13,
#          spread: 13,
#          finds: 13,
#          gives: 13,
#          runs: 13,
#          runs: 13,
#          tackles: 13,
#          runs: 13,
#          follow: 13,
#          flies: 12,
#          fires: 12,
#          falls: 12,
#          sees: 12,
#          done: 12,
#          lower: 12,
#          pops: 12,
#          whistle: 12,
#          move: 12,
#          leaving: 12,
#          walks: 12,
#          nudges: 12,
#          move: 12,
#          return: 12,
#          announces: 12,
#          tape: 12,
#          sways: 12,
#          gives: 12,
#          rush: 12,
#          leave: 12,
#          gets: 12,
#          gives: 12,
#          start: 12,
#          talking: 12,
#          leaves: 12,
#          walks: 12,
#          sits: 12,
#          pulls: 12,
#          thawed: 12,
#          seen: 12,
#          tosses: 12,
#          skips: 12,
#          walks: 12,
#          stops: 12,
#          leave: 12,
#          walk: 12,
#          opens: 12,
#          plucks: 12,
#          set: 12,
#          closes: 12,
#          heads: 12,
#          gets: 12,
#          drives: 12,
#          watches: 12,
#          go: 12,
#          turns: 12,
#          face: 12,
#          receding: 12,
#          rises: 12,
#          becomes: 12,
#          -: 12,
#          position: 12,
#          becomes: 12,
#          stunned: 12,
#          saw: 12,
#          turns: 12,
#          breaks: 12,
#          goes: 12,
#          starts: 12,
#          firing: 12,
#          reaches: 12,
#          takes: 12,
#          gives: 12,
#          keeps: 12,
#          opens: 12,
#          cackling: 12,
#          opens: 12,
#          begins: 12,
#          spraying: 12,
#          cackling: 12,
#          begins: 12,
#          zoom: 12,
#          sees: 12,
#          goes: 12,
#          forcing: 12,
#          guarding: 12,
#          jump: 12,
#          heard: 12,
#          catch: 12,
#          try: 12,
#          end: 12,
#          move: 12,
#          spins: 12,
#          looks: 12,
#          's: 12,
#          arrive: 12,
#          hanging: 12,
#          set: 12,
#          removed: 12,
#          rigged: 12,
#          pulls: 12,
#          releases: 12,
#          triggers: 12,
#          hits: 12,
#          supposed: 12,
#          land: 12,
#          babbles: 12,
#          approaches: 12,
#          pisses: 12,
#          walks: 12,
#          rises: 12,
#          approaches: 12,
#          sniffs: 12,
#          rises: 12,
#          approaches: 12,
#          turns: 12,
#          craps: 12,
#          stands: 12,
#          step: 12,
#          begin: 12,
#          ripping: 12,
#          rips: 12,
#          spits: 12,
#          throws: 12,
#          leaves: 12,
#          steps: 12,
#          repeating: 12,
#          did: 12,
#          follows: 12,
#          steps: 12,
#          flaps: 12,
#          get: 12,
#          jumps: 12,
#          heads: 12,
#          stand: 12,
#          frozen: 12,
#          leave: 12,
#          remains: 12,
#          turns: 12,
#          watch: 12,
#          leave: 12,
#          leaves: 12,
#          runs: 12,
#          jump: 12,
#          begins: 12,
#          smoke: 12,
#          swim: 12,
#          reaches: 12,
#          turns: 12,
#          wait: 12,
#          blows: 12,
#          shields: 12,
#          reaches: 12,
#          walks: 12,
#          brings: 12,
#          presses: 12,
#          release: 12,
#          throws: 12,
#          runs: 12,
#          levels: 12,
#          strikes: 12,
#          catches: 12,
#          disappear: 12,
#          brings: 12,
#          puts: 12,
#          maintaining: 12,
#          leans: 12,
#          get: 12,
#          look: 12,
#          stares: 12,
#          are: 12,
#          left: 12,
#          's: 12,
#          seated: 12,
#          has: 12,
#          leans: 12,
#          whispers: 12,
#          turns: 12,
#          walk: 12,
#          enter: 12,
#          begin: 12,
#          checking: 12,
#          wear: 12,
#          gets: 12,
#          gets: 12,
#          outfit: 12,
#          gets: 12,
#          spray: 12,
#          measures: 12,
#          born: 12,
#          begins: 12,
#          shimmy: 12,
#          stretch: 12,
#          takes: 12,
#          blowing: 12,
#          crashes: 12,
#          shearing: 12,
#          kills: 12,
#          buzzes: 12,
#          heads: 12,
#          goes: 12,
#          follows: 12,
#          hands: 12,
#          shows: 12,
#          sees: 12,
#          roughed: 12,
#          shows: 12,
#          's: 12,
#          shows: 12,
#          throws: 12,
#          hangs: 12,
#          stunned: 12,
#          gets: 12,
#          laughs: 12,
#          pour: 12,
#          start: 12,
#          firing: 12,
#          scatter: 12,
#          try: 12,
#          escape: 12,
#          jump: 12,
#          begin: 12,
#          firing: 12,
#          arrive: 12,
#          begin: 12,
#          firing: 12,
#          turns: 12,
#          goes: 12,
#          kicks: 12,
#          spreads: 12,
#          slashes: 12,
#          moves: 12,
#          intervene: 12,
#          continues: 12,
#          rake: 12,
#          notices: 12,
#          coming: 12,
#          slashes: 12,
#          run: 12,
#          flying: 12,
#          drops: 12,
#          scoops: 12,
#          rips: 12,
#          winged: 12,
#          abduct: 12,
#          walk: 12,
#          scoop: 12,
#          drop: 12,
#          look: 12,
#          fly: 12,
#          fails: 12,
#          see: 12,
#          closed: 12,
#          firing: 12,
#          starts: 12,
#          climbing: 12,
#          gets: 12,
#          intercept: 12,
#          decides: 12,
#          electrocuting: 12,
#          get: 12,
#          works: 12,
#          appear: 12,
#          shown: 12,
#          look: 12,
#          love: 12,
#          take: 12,
#          shot: 12,
#          looks: 12,
#          looks: 12,
#          notices: 12,
#          looking: 12,
#          had: 12,
#          had: 12,
#          goes: 12,
#          rip: 12,
#          watches: 12,
#          goes: 12,
#          rips: 12,
#          goes: 12,
#          tears: 12,
#          ...})

# %% [markdown]
# ## Custom function to remove brackets

# %%
df['scripts'].replace(to_replace="\[.*?]", value="", regex=True, inplace=True)

# %%
df.scripts[2]

# %%
from __future__ import unicode_literals
import spacy,en_core_web_sm
import textacy

# %%
type(matches)

# %%
for i in matches:
    print(i)

# %%
re.sub("End of {title}.*", '', script, flags=re.DOTALL)

# %%
pattern = 'Cartman'
c_matches = re.findall(pattern, script)

# %%
pattern = 'Kenny'
k_matches = re.findall(pattern, script)

# %%
pattern = 'Stan'
s_matches = re.findall(pattern, script)

# %%
pattern = 'Kyle'
ky_matches = re.findall(pattern, script)

# %%
len(matches)

# %%
len(k_matches)

# %%
len(s_matches)

# %%
len(ky_matches)
