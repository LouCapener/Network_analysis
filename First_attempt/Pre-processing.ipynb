# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import os
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
import spacy
import numpy as np
from spacy import displacy
import re

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 16.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.3)
# Requirement already satisfied: jinja2 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/loucap/anaconda3/envs/r_env2/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
NER = spacy.load("en_core_web_sm")

# %% [markdown]
# # Read-in data

# %%
df = pd.read_csv('Raw_data/scripts.csv')

# %%
# Quick glance at data

df.head()

# %% [markdown]
# # Sentence tokenisation

# %%
# Let's have a look at the first script for S1:E1

df.scripts[0]
# Out:
# 'Cartman Gets an Anal Probe/Script | South Park Archives | Fandom\nSouth Park ArchivesA new Paramount Plus Special Premieres May 24th on Paramount Plus! Click to learn more HERE\nJoin the SPA Discord to discuss the announcement with other fans and wiki editors. HEREREAD MORE\nSouth Park Archives\nExplore\nMain Page\nAll Pages\nCommunity\nInteractive Maps\nRecent Blog Posts\nSouth Park: The End of Obesity\nCharacters\nMain Characters\nEric Cartman\nStan Marsh\nKyle Broflovski\nKenny McCormick\nMajor Characters\nButters Stotch\nHerbert Garrison\nRandy Marsh\nFamilies\nMain Characters\' Families\nOther Characters\' Families\nPossible Families\nSupporting Characters\nAnnie Knitts\nBebe Stevens\nClyde Donovan\nCraig Tucker\nDougie O\'Connell\nMore...\nOther Characters\nSchool Characters\nCreatures\nCelebrities\nAlter Egos\nGroups\nUnnamed Characters\nAll Characters\nEpisodes\nLatest Episode\nSeasons 1-5\nSeason One\nSeason Two\nSeason Three\nSeason Four\nSeason Five\nSeasons 6-10\nSeason Six\nSeason Seven\nSeason Eight\nSeason Nine\nSeason Ten\nSeasons 11-15\nSeason Eleven\nSeason Twelve\nSeason Thirteen\nSeason Fourteen\nSeason Fifteen\nSeasons 16-20\nSeason Sixteen\nSeason Seventeen\nSeason Eighteen\nSeason Nineteen\nSeason Twenty\nSeasons 21-24\nSeason Twenty-One\nSeason Twenty-Two\nSeason Twenty-Three\nSeason Twenty-Four\nSeasons 25-28\nSeason Twenty-Five\nSeason Twenty-Six\nSeason Twenty-Seven\nSeason Twenty-Eight\nGames & More\nVideo Games\nSouth Park: Snow Day!\nSouth Park: The Stick of Truth\nSouth Park: The Fractured But Whole\nSouth Park: Phone Destroyer\nMovies\nThe End of Obesity\nLocations\nSongs\nMerchandise\nSnow Day Project Page\nFANDOM\nFan Central\nBETA\nGames\nAnime\nMovies\nTV\nVideo\nWikis\nExplore Wikis\nCommunity Central\nStart a Wiki\nDon\'t have an account?\nRegister\nSign In\nAdvertisement\nSign In\nRegister\nSouth Park Archives\n6,943pages\nExplore\nMain Page\nAll Pages\nCommunity\nInteractive Maps\nRecent Blog Posts\nSouth Park: The End of Obesity\nCharacters\nMain Characters\nEric Cartman\nStan Marsh\nKyle Broflovski\nKenny McCormick\nMajor Characters\nButters Stotch\nHerbert Garrison\nRandy Marsh\nFamilies\nMain Characters\' Families\nOther Characters\' Families\nPossible Families\nSupporting Characters\nAnnie Knitts\nBebe Stevens\nClyde Donovan\nCraig Tucker\nDougie O\'Connell\nMore...\nOther Characters\nSchool Characters\nCreatures\nCelebrities\nAlter Egos\nGroups\nUnnamed Characters\nAll Characters\nEpisodes\nLatest Episode\nSeasons 1-5\nSeason One\nSeason Two\nSeason Three\nSeason Four\nSeason Five\nSeas
df['scripts'] = df['scripts'].apply(lambda x: re.sub(r'^.*?Cast','Cast', x, flags = re.DOTALL))

# %%
df
# Out:
#         season  episode                            title  \
# 0     SEASON 1        1       Cartman Gets an Anal Probe
# 1     SEASON 1        2                 Weight Gain 4000
# 2     SEASON 1        3                          Volcano
# 3     SEASON 1        4   Big Gay Al's Big Gay Boat Ride
# 4     SEASON 1        5  An Elephant Makes Love to a Pig
# ..         ...      ...                              ...
# 316  SEASON 26        2       The Worldwide Privacy Tour
# 317  SEASON 26        3                  Japanese Toilet
# 318  SEASON 26        4                    Deep Learning
# 319  SEASON 26        5               DikinBaus Hot Dogs
# 320  SEASON 26        6                     Spring Break
#
#                                                    url  \
# 0    https://southpark.fandom.com/wiki/Cartman_Gets...
# 1    https://southpark.fandom.com/wiki/Weight_Gain_...
# 2     https://southpark.fandom.com/wiki/Volcano/Script
# 3    https://southpark.fandom.com/wiki/Big_Gay_Al%2...
# 4    https://southpark.fandom.com/wiki/An_Elephant_...
# ..                                                 ...
# 316  https://southpark.fandom.com/wiki/The_Worldwid...
# 317  https://southpark.fandom.com/wiki/Japanese_Toi...
# 318  https://southpark.fandom.com/wiki/Deep_Learnin...
# 319  https://southpark.fandom.com/wiki/DikinBaus_Ho...
# 320  https://southpark.fandom.com/wiki/Spring_Break...
#
#                                                scripts
# 0    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# 1    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# 2    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# 3    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# 4    Cast\nStan Marsh\nKyle Broflovski\nEric Cartma...
# ..                                                 ...
# 316  Cast\nKyle Broflovski\nStan Marsh\nEric Cartma...
# 317  Cast\nRandy Marsh\nSharon Marsh\nShelley Marsh...
# 318  Cast\nBebe Stevens\nNelly\nRed McArthur\nNicho...
# 319  Cast\nButters Stotch\nEric Cartman\nStan Marsh...
# 320  Cast\nStan Marsh\nRandy Marsh\nHerbert Garriso...
#
# [321 rows x 5 columns]

# %%
fep = "DikinBaus Hot Dogs"

# %%
pat = rf"End of {fep}.*"

# %%
test_case = df.scripts[319]

# %%
new = re.sub(pat, '', test_case, flags = re.DOTALL)

# %%
new
# Out:
# 'Cast\nButters Stotch\nEric Cartman\nStan Marsh\nKyle Broflovski\nLiane Cartman\nManager\nChild\nKenny McCormick\nBanker\nReporter\nConstruction Worker\nStephen Stotch\nLinda Stotch\nTeenager\nDarryl Weathers\nScott Malkinson\nToddler\nClyde Donovan\nFemale Customer\nMale Customer\nJimbo Kern\nMayor McDaniels\nMover\nScript\nDikinBaus Hot Dogs\nThe four boys are playing basketball, when Butters runs up to them.\nButters\nFellas! Hey, fellas, you\'re not gonna believe it!\nCartman\nButters, what the hell are you wearing?\nButters\nI got a job over at the ice cream shop! Guess what? I got my very first paycheck!\nCartman\nThat\'s not fair! I want a paycheck!\nButters\nMy dad told me if I got a job, we could put my paychecks in my very own bank account.\nCartman\nI want a bank account!\nStan\nI didn\'t know kids could get jobs.\nButters\nYeah, well, I guess these days it\'s really hard for businesses to find people to work, so they\'ll take whatever they can get.\nCartman\nI want to take whatever I can get!\nButters\nIt\'s what they call the Great Resignation Labor Shortage. So now, if you have your parents\' permission, there are some jobs they\'ll even let kids do.\nCartman\nThat is messed up! Why does he get to have a job? I want a job!\nKyle\nYou wouldn\'t last 4 hours on a job, fatass.\nCartman\nExcuse me? That\'s easy for you to say! You don\'t need a job, \'cause you live in a nice house! I have to live in a shithole like Kenny does! It\'s not fair that some people in our country are given the opportunity for employment, while others aren\'t!\nCartman starts to leave.\nCartman\nI\'m gonna tell my mom!\nCartman leaves.\nScene cuts to Cartman\'s house, where Liane is on the couch watching TV and knitting. Cartman enters.\nCartman\nMom! Mom! I need your permission to get a job.\nLiane\nOh, you\'re too young to have a job, sweetie!\nCartman\nButters got a job!\nLiane ignores Cartman\nCartman\nMom! Look at this shithole we live in! Somebody has to get a job, \'cause you just sit on your ass all day!\nLiane\nI had a job, Eric, but you got me fired because you wanted me taking care of you, and that\'s why we had to sell our house!\nCartman\nYes! Right! Because I\'m the man of the house. You\'re supposed to take care of me, and I\'m supposed to go get a job. You really expect us to live like this the rest of our lives? This is not a proper place to raise a child! You have to go let me find a job, Mom!\nLiane\nEric, the truth is, I don\'t think you\'d last 4 hours at a job.\nCartman\nOh! Now you sound like Kyle! Do you run Hollywood with him? Are you a Jew too, Mom?\nLiane\nAlright, Eric, fine! You want to go get a job and have a little dose of reality? Maybe it\'ll be good for you.\nCartman\nThanks, Mom! I love you!\nCartman leaves.\nScene cuts to the ice cream store where Butters is working.\nButters\nLoo, loo, loo, I\'m serving ice cream. Loo, loo, loo, you\'ll eat it too. Loo, loo, loo, I\'m serving ice cream...\nButters goes to the checkout counter and hands ice cream to a customer.\nButters\nOkay, and the pistachio maple cream. Let me know if you need extra napkins for your table, and have a creamy day!\nCartman enters the store.\nButters\nOh, hey, Eric!\nCartman\nHey, Butters! I\'m here for my job.\nButters\nWhat are you talking about?\nCartman\nMy mom gave me permission; I can start work now. What do I do?\nButters\nWell, but, Eric, this is my job.\nCartman\nYeah, I want your job, sitting around eating ice cream. Sounds fun.\nButters\nEric, there\'s a lot more to it than that, and I already do this job, so...\nManager\nEverything alright, Butters?\nButters\nOh. Yes, Mr. Sullivan. I was just...\nCartman\nHello, sir. I\'m a dear friend of Butters. He told me all about this place and said I should get permission from my mom to work here.\nManager\nOh. Well, uh, I do need all the help I can get. Butters, can you vouch for him? Is he trustworthy and reliable?\nButters\nUh, oh, uh...\nCartman glares at Butters.\nButters\nUm, okay ...

# %%
def match_title(script):
    for title in df.title:
        if re.search(title, script, flags=re.DOTALL):
            script = re.sub(rf"End of {title}.*", f'End of {title}', script, flags=re.DOTALL)
    return script
# FINISH UP

# %%
df['scripts'] = df['scripts'].apply(match_title)

# %%
df
# Out:
#         season  episode                            title  \
# 0     SEASON 1        1       Cartman Gets an Anal Probe
# 1     SEASON 1        2                 Weight Gain 4000
# 2     SEASON 1        3                          Volcano
# 3     SEASON 1        4   Big Gay Al's Big Gay Boat Ride
# 4     SEASON 1        5  An Elephant Makes Love to a Pig
# ..         ...      ...                              ...
# 316  SEASON 26        2       The Worldwide Privacy Tour
# 317  SEASON 26        3                  Japanese Toilet
# 318  SEASON 26        4                    Deep Learning
# 319  SEASON 26        5               DikinBaus Hot Dogs
# 320  SEASON 26        6                     Spring Break
#
#                                                    url  \
# 0    https://southpark.fandom.com/wiki/Cartman_Gets...
, okay, let\'s, let\'s try and have none of that today. In John 3:16, the Gospel tells us how God so loved the world he gave to us his only Son\nStephen\nAnd a Catholic priest raped him. [all laugh]\nFr. Maxi\nOkay, okay, Co-come on guys, Nu-now, what greater gift could the Lord has given to us?\nWoman\nChildren\'s underwear which priests couldn\'t pull down so easily? [all laugh]\nFr. Maxi\nOkay, let\'s, let\'s try to compose ourselves. Let\'s try and just get through this first one, okay guys? What does it mean that the Lord gave us his only begotten Son?\nTownsman 1\nIt means that if you\'re a cute boy at a Catholic priest\'s swimming party you\'d better be gettin\'! [The congregants laugh. Randy gets carried and falls on the aisle laughing and pounding his fists on the floor.]\nThe Church. Mass ends and the congregant\'s exit.\nRandy\nOh, that was a great one, Nelson. Salvation in a little boy\'s mouth. I\'m gonna post that one for sure.\nWoman 2\nWho said the thing about naked boy salad?\nStephen\nOh that was Linda!\nJimbo\nWell, see ya next week, everybody! [waves and moves off to his left]\nOthers\nYeah, see ya! See ya! Bye.\nThe Marsh car, on the way home\nStan\nI really don\'t understand the point of all that.\nRandy\n[chuckles] Yeah, well, I used to think that about church when I was a kid too.\nStan\nBut back then I don\'t know if church was that stupid.\nRandy\nHey, don\'t say things like that, Stan! You wanna go to fuckin\' Hell?\nThe Church, sometime later. Father Maxi is blowing out the candles, looking sad. Butters enters quietly through the back. Maxi walks to the front pew and sits down, then sighs. Butters walks up to him\nButters\nFath ...

# %% [markdown]
# # Export csv.. for now

# %%
os.getcwd()
# Out:
# '/Users/loucap/Documents/GitWork/SNA'

# %%
regex_df = df.to_csv('Data/regex_df.csv', index = False)

# %%
doc = NER(df.scripts[320])

# %%
html = displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cast<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stan Marsh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Randy Marsh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Herbert Garrison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick
# Tolkien Black
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve Black
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linda Black
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sharon Marsh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alonzo Fineski
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maga Store Salesman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>Officer
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Johnson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>Script<br>Spring Break<br>Scene cuts to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  at home. Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Garrison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  enters.<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Garrison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>Hey,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# !<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick
# Oh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Hey, Herb.<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Garrison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>So, you know what
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  is, right?<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick
# Um
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , is it
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Easter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ?<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Garrison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>No, it's my spring break! No school for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seven days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ! And guess what? Go pack your things because you and I are going on a big, romantic trip!<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rick
# Really
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ?<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Garrison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# <br>I just came from the travel agent. We're gonna spend
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five nights
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Myrtle

# %%
character_df = pd.read_csv('../Data/main_cat.csv')

# %%
character_df.loc[1176, 'Character'] = 'Member Berries'

# %%
character_df[character_df.Character.isna()]

# %%
import re
character_df['Character'] = character_df['Character'].apply(lambda x: re.sub("[\(].*?[\)]", "", x))
character_df['First_name'] = character_df['Character'].apply(lambda x: x.split(' ',1)[0])

# %%
filtered = character_df[character_df['Character'].str.contains(r'\b(Mr\. |Dr\. |[a-zA-Z]+\'s)\b')]

# %%
filtered[filtered.Character.str.contains('Mr.')].head(20)

# %%
s = character_df.Character

# %%
s.str.split(pat = None, n = 1).str[0]

# %%
test = test.replace('\n', ' ')

# %%
test

# %%
sample = "Oh crap. Here we go again...I don't believe this. Believe what?"

# %%
sent_tokenize(sample)

# %%
sample = "The young girl took a walk. Hey you! Get over here now! The man yelled at the girl. I must've told you I talk to you...NOW"

# %%
sent_tokenize(sample)

# %%
sentence_tokens = sent_tokenize(test)
print("Sentence Tokens:", sentence_tokens)
